# %%
import pickle
from model import Node, categorize_next, display_lazy_tree, format_node, format_time

# %%
import chardet

with open("amazon_products.csv", 'rb') as f:
    result = chardet.detect(f.read(8*1024*1024))
    print(result)
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
import pandas as pd
df = pd.read_csv("amazon_products.csv", encoding=result["encoding"])

# %%
df = df.sample(20000)
df.head()
# Out:
#                asin                                              title  \
# 1150788  B002JTG0PO  Polk Audio MC60 2-Way In-Ceiling 6.5" Speaker ...
# 477829   B00S15FGE6   Chad Uniform Oxford (Toddler/Little Kid/Big Kid)
# 1126164  B06ZYGB2NM  CRAFTMEMORE 1/4" Hole Size 100 Sets Gunmetal B...
# 695195   B09364MYWD  Mini Size Glass Teapot Tea Kettle-with Stainle...
# 128464   B0BK8B3Y23  Flying Orb Ball Toy, Hover/Boomerang Ball, Fly...
#
#                                                     imgUrl  \
# 1150788  https://m.media-amazon.com/images/I/81-1RNG2Np...
# 477829   https://m.media-amazon.com/images/I/61o+VZ39Oa...
# 1126164  https://m.media-amazon.com/images/I/616S8TsTOE...
# 695195   https://m.media-amazon.com/images/I/71Gqk22o0A...
# 128464   https://m.media-amazon.com/images/I/71n+Q5Sb0L...
#
#                                    productURL  stars  reviews   price  \
# 1150788  https://www.amazon.com/dp/B002JTG0PO    4.7        0  149.00
# 477829   https://www.amazon.com/dp/B00S15FGE6    4.5        0   56.49
# 1126164  https://www.amazon.com/dp/B06ZYGB2NM    4.3        0   12.99
# 695195   https://www.amazon.com/dp/B09364MYWD    4.4        0    9.98
# 128464   https://www.amazon.com/dp/B0BK8B3Y23    4.0      632   32.00
#
#          listPrice  category_id  isBestSeller  boughtInLastMonth
# 1150788        0.0           82         False                  0
# 477829        65.0           97         False                  0
# 1126164        0.0            6         False                  0
# 695195         0.0          162         False                800
# 128464         0.0          228         False                100

# %%
with open("./tree_v4_improved.pkl", "rb") as f:
    root = pickle.load(f)

# %%
from typing import Callable, Optional, Tuple
from langchain_core.language_models.chat_models import BaseChatModel

from model.data import TokenCounts

def classify(item_description: str, root: Node, create_llm: Callable[[], BaseChatModel]) -> Tuple[Optional[Node], TokenCounts]:
    def classify_recur(item_description: str, node: Node) -> Tuple[Optional[Node], TokenCounts]:
        if node.is_leaf():
            return node, TokenCounts()
        children = [*node.children]
        all_tokens = TokenCounts()
        print(f"Entering {node.condition}")
        while len(children) > 0:
            print(f"Trying {node.condition} with {len(children)} unexplored child nodes.")
            choice, tokens = categorize_next(item_description=item_description, nodes=children, create_llm=create_llm)
            print(f"Chose {choice.condition if choice else "None"}")
            all_tokens += tokens
            if choice is None:
                print(f"Retrying previous node with mask.")
                return (None, all_tokens)
            
            print(f"Trying chosen subtree.")
            result, tokens = classify_recur(item_description=item_description, node=choice)
            print(f"Subtree yielded choice {result.condition if result else "None"}.")
            all_tokens += tokens
            if result is not None:
                print(f"Yielding subtree result {result.condition}")
                return (result, all_tokens)
            
            print(f"Retrying {node.condition} with mask.")
            children.remove(choice)
            
        return None, all_tokens
            
    return classify_recur(item_description=item_description, node=root)

# %%
from langchain_ollama import ChatOllama
create_llm = lambda: ChatOllama(
    model="qwen2.5:32b",
    # temperature=0,
)

# %%
display_lazy_tree(root, max_initial_depth=5)
# Out:
# VBox(children=(FigureWidget({
#     'data': [{'branchvalues': 'total',
#               'ids': [9d02c85c-ac42-4982-…

# %%
from pydantic import BaseModel, Field
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import HumanMessage
from langchain_community.callbacks import get_openai_callback


class Description(BaseModel):
    reasoning: str = Field(description="Reasoning on your choice.")
    description: str = Field(description="The shortened description")

def prompt_tentative_description(item_description: str, create_llm: Callable[[], BaseChatModel]) -> Tuple[Description, TokenCounts]:
    template = """
    From the given e-commerce item description give a simplified short, generic description that would be useful in categorizing an item into product standardizations.
    From specific product names and branding provide a description that includes the true nature of the product.
    Use the given tool to provide your answer.
    
    {item}
    """.strip()
    
    prompt = ChatPromptTemplate.from_template(template)
    prompt = prompt.format(item=item_description)
    
    with get_openai_callback() as cb:
        llm = create_llm().with_structured_output(Description)
        response = llm.invoke([HumanMessage(prompt)])
        
    return response, TokenCounts(prompt=cb.prompt_tokens, completion=cb.completion_tokens, total=cb.total_tokens)

# %%
from ipywidgets import IntProgress, VBox, Label
from IPython.display import display
import time

def create_classification_sample(df: pd.DataFrame, root: Node) -> Tuple[pd.DataFrame, TokenCounts]:
    items: list[dict[str, any]] = []
    all_tokens = TokenCounts()

    total_rows = len(df)
    progress_bar = IntProgress(min=0, max=total_rows, description='Progress:', bar_style='info')
    label = Label(value=f"0/{total_rows} items processed")
    time_label = Label(value="Estimating time...")
    display(VBox([progress_bar, label, time_label]))

    processed_rows = 0
    start_time = time.time()

    for i, row in df.iterrows():
        print(f"\tItem: {row['title']}")
        short_desc, desc_tokens = prompt_tentative_description(item_description=row["title"], create_llm=create_llm)
        print(f"\tShort Desc: {short_desc.description}")
        node, tokens = classify(item_description=short_desc.description, root=root, create_llm=create_llm)
        record = {
            "item": row["title"],
            "imputed_desc": short_desc.description,
            "classification": format_node(node) if node else "None"
        }
        items.append(record)
        all_tokens += tokens + desc_tokens

        processed_rows += 1
        elapsed_time = time.time() - start_time
        progress_bar.value = processed_rows
        label.value = f"{processed_rows}/{total_rows} items processed"
        estimated_total_time = elapsed_time / processed_rows * total_rows
        remaining_time = estimated_total_time - elapsed_time
        time_label.value = f"Estimated remaining time: {format_time(remaining_time)}"

    result = pd.DataFrame(items)
    return result, all_tokens

# %%
df_sample = df.sample(100)

args: list[dict[str,any]] = [
    {
        "model_file": "tree_v3_improved.pkl",
        "output_file": "classifications_v3_improved.csv"
    },
    {
        "model_file": "tree_v3.pkl",
        "output_file": "classifications_v3.csv"
    },
    {
        "model_file": "tree_v4_improved.pkl",
        "output_file": "classifications_v4_improved.csv"
    },
    {
        "model_file": "tree_v4.pkl",
        "output_file": "classifications_v4.csv"
    },
]

output_dir = "classification_results"
tokens_output_file = "tokens.csv"

import os
import time

os.makedirs(output_dir, exist_ok=True)


tokens_dicts = []
for argset in args:
    start_time = time.time()
    with open(argset["model_file"], "rb") as f:
        root = pickle.load(f)
    
    out_df, tokens = create_classification_sample(df_sample, root)
    elapsed_time = time.time() - start_time
    tokens_dicts.append({
        **argset,
        "prompt": tokens.prompt,
        "completion": tokens.completion,
        "total": tokens.total,
        "elapsed_seconds": elapsed_time
    })
    out_df.to_csv(f'{output_dir}/{argset["output_file"]}')
    print(f"Saved classifications from {argset['model_file']} to {output_dir}/{argset['output_file']}")
    
tokens_df = pd.DataFrame(tokens_dicts)
tokens_df.to_csv(tokens_output_file)
# Out:
# VBox(children=(IntProgress(value=0, bar_style='info', description='Progress:'), Label(value='0/100 items proce…
# 	Item: WOCRAFT 100g(About 76pcs) Craft Supplies Small Antique Bronze Silver Sun Moon Star Charms Pendants for Jewelry Making Findings Crafting Accessory for DIY Necklace Bracelet (M206)
# 	Short Desc: Small antique bronze silver sun, moon, star charms for DIY jewelry
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Dinosaur Swaddle Blanket, Dinosaur Baby Stuff, Newborn Soft Wearable Blanket Swaddle Up Sleep Sacks for Boys Girls Dinosaur Shower Gift
# 	Short Desc: Soft wearable blanket or sleep sack for newborns, suitable for both boys and girls.
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose Personal & Home Essentials
# Trying chosen subtree.
# Entering Personal & Home Essentials
# Trying Personal & Home Essentials with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 10 unexplored child nodes.
# Chose Health & Personal Care Essentials
# Trying chosen subtree.
# Entering Health & Personal Care Essentials
# Trying Health & Personal Care Essentials with 9 unexplored child nodes.
# Chose Health & Household
# Trying chosen subtree.
# Subtree yielded choice Health & Household.
# Yielding subtree result Health & Household
# Subtree yielded choice Health & Household.
# Yielding subtree result Health & Household
# 	Item: 25mm Tube Brush Stainless Steel Wire 6.3 inch Bottle Long-Handle Bristle Cleaning, 3Pcs
# 	Short Desc: Stainless Steel Long Handle Bottle Cleaning Tube Brush Set
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Food Service Equipment & Supplies
# Trying chosen subtree.
# Subtree yielded choice Food Service Equipment & Supplies.
# Yielding subtree result Food Service Equipment & Supplies
# 	Item: HDMI KVM Switch Dual Monitors 2 Computers 2 Port,2 Computers Share 2 Monitors, Monitor Switch for 2 Computers 2 Monitors UHD 4K@30Hz Downward Compatible, No Adapter Required,with Hotkey Switch
# 	Short Desc: Dual Monitor KVM Switch for Two Computers, Supports UHD 4K@30Hz, Hotkey Switch Included
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: 12 PCS Mini Acrylic Paint Set,Washable Filled Paint Sets for Kids & Adults,Mini Paint Set with 8 Vivid Colors & Paint Brushes,Kids Paint Bulk Set Acrylic Paint Strips for Classroom Home Party Favors
# 	Short Desc: Set of 12 acrylic paint strips with 8 vibrant colors and paint brushes suitable for kids and adults, ideal for classroom activities, home use, or party favors.
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Leisure & Hobby Supplies
# Trying chosen subtree.
# Entering Leisure & Hobby Supplies
# Trying Leisure & Hobby Supplies with 15 unexplored child nodes.
# Chose Painting, Drawing & Art Supplies
# Trying chosen subtree.
# Subtree yielded choice Painting, Drawing & Art Supplies.
# Yielding subtree result Painting, Drawing & Art Supplies
# Subtree yielded choice Painting, Drawing & Art Supplies.
# Yielding subtree result Painting, Drawing & Art Supplies
# 	Item: CoBak Case for Remarkable 2 Paper Tablet - Lightweight and Hard Back Shell Protective Book Folio Cover with Built-in Pen Holder - for 10.3" 2020 Released (Emerald)
# 	Short Desc: Protective book-style folio case with pen holder for use with 10.3" tablets
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Stationery & Gift Wrapping Supplies
# Trying chosen subtree.
# Subtree yielded choice Stationery & Gift Wrapping Supplies.
# Yielding subtree result Stationery & Gift Wrapping Supplies
# 	Item: Lego Star Wars: The Complete Saga - Nintendo Wii
# 	Short Desc: Lego-themed Star Wars video game for Wii
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Kids' Development & Play Gear
# Trying chosen subtree.
# Entering Kids' Development & Play Gear
# Trying Kids' Development & Play Gear with 15 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Children's Education & Apparel with mask.
# Trying Children's Education & Apparel with 7 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose Leisure & Hobby Supplies
# Trying chosen subtree.
# Entering Leisure & Hobby Supplies
# Trying Leisure & Hobby Supplies with 15 unexplored child nodes.
# Chose Multi-Platform Gaming & Services
# Trying chosen subtree.
# Entering Multi-Platform Gaming & Services
# Trying Multi-Platform Gaming & Services with 4 unexplored child nodes.
# Chose Gaming Systems & Titles
# Trying chosen subtree.
# Entering Gaming Systems & Titles
# Trying Gaming Systems & Titles with 13 unexplored child nodes.
# Chose Wii Games, Consoles & Accessories
# Trying chosen subtree.
# Subtree yielded choice Wii Games, Consoles & Accessories.
# Yielding subtree result Wii Games, Consoles & Accessories
# Subtree yielded choice Wii Games, Consoles & Accessories.
# Yielding subtree result Wii Games, Consoles & Accessories
# Subtree yielded choice Wii Games, Consoles & Accessories.
# Yielding subtree result Wii Games, Consoles & Accessories
# Subtree yielded choice Wii Games, Consoles & Accessories.
# Yielding subtree result Wii Games, Consoles & Accessories
# 	Item: QMDECOR Rectangle Sparkling Decorative Wall Mirror for Home Decoration with Silver Crystal Crush Diamond Décor, Dimention16x20x1 inch, Wall Hang Frameless Mirrors Glass Diamond Décor.
# 	Short Desc: Frameless rectangular wall mirror with sparkling silver crystal diamond decorations, dimensions 16x20 inches.
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Anlan-angel Bowl Dish Resin Mold Tealight Candle Holder Resin Molds Jewelry Tray Epoxy Casting Mold Lotus Rose Silicone Molds for Resin DIY Jewelry Storage Home Table Decor (White)
# 	Short Desc: Resin and Silicone Mold for DIY Projects
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Leisure & Hobby Supplies
# Trying chosen subtree.
# Entering Leisure & Hobby Supplies
# Trying Leisure & Hobby Supplies with 15 unexplored child nodes.
# Chose Arts & Crafts Supplies
# Trying chosen subtree.
# Subtree yielded choice Arts & Crafts Supplies.
# Yielding subtree result Arts & Crafts Supplies
# Subtree yielded choice Arts & Crafts Supplies.
# Yielding subtree result Arts & Crafts Supplies
# 	Item: LXun Upgraded HU460AM-01 460W Power Supply Compatible with Dell XPS 8930 8920 8910 8900 8700 8300 Alien-Ware Aurora R5 Replace DPS-460DB-15 AC460AM-01 WY7XX WC1T4 D460AM-03 L350AM-00 Power Supply
# 	Short Desc: 460W Power Supply for Dell Computers
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: 10 Pieces Sublimation Blank Christmas Ornament Sublimation Aluminum White Blank Pendants with Ribbon for DIY Crafting Blanks Personalized Hanging Christmas Tree Home Decoration
# 	Short Desc: Blank Aluminum Christmas Ornaments for DIY Sublimation Crafting
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Leisure & Hobby Supplies
# Trying chosen subtree.
# Entering Leisure & Hobby Supplies
# Trying Leisure & Hobby Supplies with 15 unexplored child nodes.
# Chose Arts & Crafts Supplies
# Trying chosen subtree.
# Subtree yielded choice Arts & Crafts Supplies.
# Yielding subtree result Arts & Crafts Supplies
# Subtree yielded choice Arts & Crafts Supplies.
# Yielding subtree result Arts & Crafts Supplies
# 	Item: Keter Factor 8x8 Foot Large Resin Outdoor Storage Shed with Floor for Patio Furniture, Lawn Mower, and Bike Storage
# 	Short Desc: Outdoor Resin Storage Shed with Floor
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: 407 Pieces SAE Universal O-Ring Kit, Set of 32 USA Standard Sizes, Buna-N 70A, Rubber Seals O Rings, for Faucet, Professional Plumbing, Automotive | BUSY-CORNER
# 	Short Desc: O-Ring Kit with 407 pieces in 32 USA standard sizes made of Buna-N rubber with 70A hardness for use in plumbing and automotive applications.
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Industrial Supplies & Equipment
# Trying chosen subtree.
# Entering Industrial Supplies & Equipment
# Trying Industrial Supplies & Equipment with 15 unexplored child nodes.
# Chose Industrial Adhesives, Sealants & Lubricants
# Trying chosen subtree.
# Subtree yielded choice Industrial Adhesives, Sealants & Lubricants.
# Yielding subtree result Industrial Adhesives, Sealants & Lubricants
# Subtree yielded choice Industrial Adhesives, Sealants & Lubricants.
# Yielding subtree result Industrial Adhesives, Sealants & Lubricants
# 	Item: Halloween Tablecloth Plastic 3pcs Disposable Waterproof Rectangular Tablecloth Halloween Pumpkin Patterns Table Cover for Halloween Party Supplies Decoration Dinner Party Horror Party 54x108 inch
# 	Short Desc: Disposable Waterproof Rectangular Tablecloth Set (3pcs) with Halloween Pumpkin Patterns, 54x108 inch
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Stationery & Gift Wrapping Supplies
# Trying chosen subtree.
# Subtree yielded choice Stationery & Gift Wrapping Supplies.
# Yielding subtree result Stationery & Gift Wrapping Supplies
# 	Item: Evergreen Sassafras Welcome My Pretties Halloween Interchangeable Entrance Doormat | Indoor and Outdoor | 22-inches x 10-inches | Non-Slip Backing | All-Season | Low Profile | Home Décor
# 	Short Desc: Indoor and Outdoor Doormat | Dimensions: 22-inches x 10-inches | Non-Slip Backing | All-Season Use | Low Profile Design | Home Décor Item
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Personal & Home Essentials
# Trying chosen subtree.
# Entering Personal & Home Essentials
# Trying Personal & Home Essentials with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Cushy Form 4-Inch Foldable Foam Floor Mattress for Camping, Travel & Dorms
# 	Short Desc: Foldable foam floor mattress for temporary sleeping
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Personal & Home Essentials
# Trying chosen subtree.
# Entering Personal & Home Essentials
# Trying Personal & Home Essentials with 12 unexplored child nodes.
# Chose Travel & Craft Essentials
# Trying chosen subtree.
# Entering Travel & Craft Essentials
# Trying Travel & Craft Essentials with 13 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Personal & Home Essentials with mask.
# Trying Personal & Home Essentials with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Thank You Banner, Thanksgiving, Friendsgiving, Thank You Party Decorations, Shiny Gold Gliter Paper Sign Decors
# 	Short Desc: Shiny Gold Glitter Paper Decorative Signs
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Stationery & Gift Wrapping Supplies
# Trying chosen subtree.
# Subtree yielded choice Stationery & Gift Wrapping Supplies.
# Yielding subtree result Stationery & Gift Wrapping Supplies
# 	Item: Wireless Charging Station for Samsung and Android Multiple Devices 3 in 1 Foldable fast wireless Charger Dock Stand for Phone Galaxy Z Flip 4/3 Z Fold S23 S22 S20 Ultra, Galaxy Watch 5/4/3 Galaxy Buds
# 	Short Desc: Wireless Charging Dock for Multiple Devices
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Women Slouch Socks 3 Pairs Extra Long Cotton Knit Knee High Thick Socks Size 9-11
# 	Short Desc: Knee-high cotton socks
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Personal & Home Essentials
# Trying chosen subtree.
# Entering Personal & Home Essentials
# Trying Personal & Home Essentials with 12 unexplored child nodes.
# Chose Gendered Apparel & Accessories
# Trying chosen subtree.
# Entering Gendered Apparel & Accessories
# Trying Gendered Apparel & Accessories with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Personal & Home Essentials with mask.
# Trying Personal & Home Essentials with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Boys' Clothing
# Trying chosen subtree.
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# 	Item: Kids Leather Belts for Boy Adjustable Belt for Kids Boys and Girls 1.1" Casual Uniform Belts
# 	Short Desc: Children's adjustable leather belt
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Boys' Clothing
# Trying chosen subtree.
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# 	Item: Premium Dell Latitude E6430 14 Inch HD Business Laptop (Intel Core i7-3520M up to 3.6GHz, 8GB DDR3 RAM, 1TB HDD USB, DVD, HDMI, VGA, Windows 10 Pro) (Renewed)
# 	Short Desc: 14 Inch Business Laptop - Windows 10 Pro (Refurbished)
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Playtex Mealtime Paw Patrol Utensils for Boys Including 1 Spoon and 1 Fork(Pack of 1)
# 	Short Desc: Children's Paw Patrol-themed utensil set including 1 spoon and 1 fork
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Kids' Development & Play Gear
# Trying chosen subtree.
# Entering Kids' Development & Play Gear
# Trying Kids' Development & Play Gear with 15 unexplored child nodes.
# Chose Baby & Toddler Feeding Supplies
# Trying chosen subtree.
# Subtree yielded choice Baby & Toddler Feeding Supplies.
# Yielding subtree result Baby & Toddler Feeding Supplies
# Subtree yielded choice Baby & Toddler Feeding Supplies.
# Yielding subtree result Baby & Toddler Feeding Supplies
# Subtree yielded choice Baby & Toddler Feeding Supplies.
# Yielding subtree result Baby & Toddler Feeding Supplies
# 	Item: 200 Count - 5" x 7" Self Seal Clear Cello Cellophane Resealable Plastic Poly Bags for A6 A7 A8 Cards & Envelopes, Bakery, Cookies, Candies
# 	Short Desc: Clear resealable plastic bags, size 5" x 7", pack of 200, suitable for packaging cards, envelopes, baked goods, and sweets.
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Packaging & Shipping Supplies
# Trying chosen subtree.
# Subtree yielded choice Packaging & Shipping Supplies.
# Yielding subtree result Packaging & Shipping Supplies
# 	Item: CNC Chain Guard Guide Protector Protection for for CR125R CR250R CRF250R CRF450R CRF250X CRF450X CR 250R CRF 2005-2007 05 06 07 2005 2006 2007
# 	Short Desc: Motorcycle Chain Guard Protector for Specific Models (CR125R, CR250R, CRF250R, CRF450R, CRF250X, CRF450X) from 2005-2007
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Vehicle Maintenance & Powersports Equipment
# Trying chosen subtree.
# Entering Vehicle Maintenance & Powersports Equipment
# Trying Vehicle Maintenance & Powersports Equipment with 7 unexplored child nodes.
# Chose Motorcycle & Powersports
# Trying chosen subtree.
# Subtree yielded choice Motorcycle & Powersports.
# Yielding subtree result Motorcycle & Powersports
# Subtree yielded choice Motorcycle & Powersports.
# Yielding subtree result Motorcycle & Powersports
# 	Item: Fashion Scarves Scarf 100% Silk Feeling Scarf Silk Like Scarves Long Lightweight Sunscreen Shawls for Women
# 	Short Desc: Women's Lightweight Silk Fashion Shawl
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Premium Toddler Toys Age 1-2, Bath Toys for Toddlers 1-3, Dinosaur Toys for Kids 2-4 3-5, 1 Year Old Girl & boy Birthday Gift, Fun DIY Slide Kit (31pcs)
# 	Short Desc: Toddler and Young Children's Toys including Bath Toys, Dinosaur Themed Items, and a DIY Slide Kit (31 pieces)
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Kids' Development & Play Gear
# Trying chosen subtree.
# Entering Kids' Development & Play Gear
# Trying Kids' Development & Play Gear with 15 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Children's Education & Apparel with mask.
# Trying Children's Education & Apparel with 7 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Clearblue Digital Pregnancy Test with Smart Countdown, 2 Tests (Pack of 2)
# 	Short Desc: Pregnancy Test Kit (Pack of 2)
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Health & Personal Care Essentials
# Trying chosen subtree.
# Entering Health & Personal Care Essentials
# Trying Health & Personal Care Essentials with 9 unexplored child nodes.
# Chose Pregnancy & Maternity Products
# Trying chosen subtree.
# Subtree yielded choice Pregnancy & Maternity Products.
# Yielding subtree result Pregnancy & Maternity Products
# Subtree yielded choice Pregnancy & Maternity Products.
# Yielding subtree result Pregnancy & Maternity Products
# 	Item: Concept One Star Wars The Mandalorian The Child Peek-A-Boo Beanie, Black, One Size
# 	Short Desc: Black Peek-A-Boo Beanie, One Size
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Baby Boys' Clothing & Shoes
# Trying chosen subtree.
# Subtree yielded choice Baby Boys' Clothing & Shoes.
# Yielding subtree result Baby Boys' Clothing & Shoes
# Subtree yielded choice Baby Boys' Clothing & Shoes.
# Yielding subtree result Baby Boys' Clothing & Shoes
# 	Item: Supershieldz (3 Pack) Designed for Microsoft Surface Duo Screen Protector, (3 Left Screen and 3 Right Screen) Anti Glare and Anti Fingerprint (Matte) Shield
# 	Short Desc: Screen Protector Pack (6 Pieces) - Anti-Glare & Anti-Fingerprint Matte Finish for Tablet/Smartphone
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Aleene's Quick Dry Tacky Glue, 4 FL OZ - 3 Pack, Multi
# 	Short Desc: 3-pack of 4 FL OZ quick-drying adhesive glue
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Stationery & Gift Wrapping Supplies
# Trying chosen subtree.
# Subtree yielded choice Stationery & Gift Wrapping Supplies.
# Yielding subtree result Stationery & Gift Wrapping Supplies
# 	Item: Anime Cute Luggage Tags for Women Girls, Set of 2 PU Leather with Full Back Privacy Cover Baggage Suitcase Tags for Travel ( 2 PCS)
# 	Short Desc: Luggage tags, set of 2, made of PU leather with privacy covers
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Personal & Home Essentials
# Trying chosen subtree.
# Entering Personal & Home Essentials
# Trying Personal & Home Essentials with 12 unexplored child nodes.
# Chose Travel & Craft Essentials
# Trying chosen subtree.
# Entering Travel & Craft Essentials
# Trying Travel & Craft Essentials with 13 unexplored child nodes.
# Chose Travel Accessories
# Trying chosen subtree.
# Subtree yielded choice Travel Accessories.
# Yielding subtree result Travel Accessories
# Subtree yielded choice Travel Accessories.
# Yielding subtree result Travel Accessories
# Subtree yielded choice Travel Accessories.
# Yielding subtree result Travel Accessories
# 	Item: Unisex-Child Speedcross Hiking Shoe
# 	Short Desc: Children's Unisex Hiking Shoe
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: IZOKIN 6Pcs Stainless Steel Heavy Duty Ceiling Eye Hooks pad Eye Plate 2"+ 6Pcs Stainless Steel snap Hook and 12Pcs Screws for Indoor or Outdoor Hanging Hooks
# 	Short Desc: Set of 6 heavy duty stainless steel ceiling eye hooks with plates, 6 snap hooks, and 12 screws for indoor or outdoor hanging applications.
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Industrial Supplies & Equipment
# Trying chosen subtree.
# Entering Industrial Supplies & Equipment
# Trying Industrial Supplies & Equipment with 15 unexplored child nodes.
# Chose Industrial Hardware
# Trying chosen subtree.
# Subtree yielded choice Industrial Hardware.
# Yielding subtree result Industrial Hardware
# Subtree yielded choice Industrial Hardware.
# Yielding subtree result Industrial Hardware
# 	Item: Trailer Jack Block: 2 Pack RV Camper Stabilizer Blocks for Travel Trailer, Up to 15,000 lbs, Use for Any Tongue Jack, Post, Foot, 5th Wheels, Round or Square or Scissor Stabilizer
# 	Short Desc: Stabilizer blocks set of 2, suitable up to 15,000 lbs, compatible with different trailer types including fifth wheels and various jack styles.
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Vehicle Maintenance & Powersports Equipment
# Trying chosen subtree.
# Entering Vehicle Maintenance & Powersports Equipment
# Trying Vehicle Maintenance & Powersports Equipment with 7 unexplored child nodes.
# Chose RV Parts & Accessories
# Trying chosen subtree.
# Subtree yielded choice RV Parts & Accessories.
# Yielding subtree result RV Parts & Accessories
# Subtree yielded choice RV Parts & Accessories.
# Yielding subtree result RV Parts & Accessories
# 	Item: JQK Magnetic Cabinet Door Catch, Stainless Steel Closet Catches with Strong Magnetic, 1.2mm Thickness Furniture Latch 30 lbs (Pack of 4), CC101-P4
# 	Short Desc: Stainless Steel Magnetic Cabinet Door Catch
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Personal & Home Essentials
# Trying chosen subtree.
# Entering Personal & Home Essentials
# Trying Personal & Home Essentials with 12 unexplored child nodes.
# Chose Building & Maintenance Supplies
# Trying chosen subtree.
# Entering Building & Maintenance Supplies
# Trying Building & Maintenance Supplies with 15 unexplored child nodes.
# Chose Building Supplies
# Trying chosen subtree.
# Subtree yielded choice Building Supplies.
# Yielding subtree result Building Supplies
# Subtree yielded choice Building Supplies.
# Yielding subtree result Building Supplies
# Subtree yielded choice Building Supplies.
# Yielding subtree result Building Supplies
# 	Item: NOVSIGHT Upgraded 9006 LED Headlight Bulbs 20000 Lumen, 600% Super Bright Low Beam HB4 LED Bulb, 90W 6500K Bright White Headlights Converstion Kit, Plug and Play, 2 Pack
# 	Short Desc: Upgraded High Brightness LED Headlight Bulbs, 2 Pack
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Vehicle Maintenance & Powersports Equipment
# Trying chosen subtree.
# Entering Vehicle Maintenance & Powersports Equipment
# Trying Vehicle Maintenance & Powersports Equipment with 7 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Bessmoso Vintage Two Fast Birthday Race Car Party Decorations Supplies Racing Theme 2nd Birthday Banner Cake Topper Checkered Flags Number Balloons for Let's go Racing Theme Sports Event Party Decor
# 	Short Desc: Racing Theme Birthday Party Decorations Set
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Stationery & Gift Wrapping Supplies
# Trying chosen subtree.
# Subtree yielded choice Stationery & Gift Wrapping Supplies.
# Yielding subtree result Stationery & Gift Wrapping Supplies
# 	Item: Mens 3 Pack Crewneck T-Shirt Cotton Hipster Hip Hop Longline Classic Top
# 	Short Desc: 3 Pack Cotton Crewneck T-Shirts - Longline Style
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Boys' Clothing
# Trying chosen subtree.
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# 	Item: Mission Critical Foldable Pouch - Gray
# 	Short Desc: Foldable storage pouch, gray
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Packaging & Shipping Supplies
# Trying chosen subtree.
# Subtree yielded choice Packaging & Shipping Supplies.
# Yielding subtree result Packaging & Shipping Supplies
# 	Item: Tom's of Maine Natural Wicked Fresh! Mouthwash, Cool Mountain Mint, 16 Ounce
# 	Short Desc: Cool mint flavored mouthwash, 16 ounce bottle
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Health & Personal Care Essentials
# Trying chosen subtree.
# Entering Health & Personal Care Essentials
# Trying Health & Personal Care Essentials with 9 unexplored child nodes.
# Chose Personal Care & Health Products
# Trying chosen subtree.
# Entering Personal Care & Health Products
# Trying Personal Care & Health Products with 12 unexplored child nodes.
# Chose Oral Care Products
# Trying chosen subtree.
# Subtree yielded choice Oral Care Products.
# Yielding subtree result Oral Care Products
# Subtree yielded choice Oral Care Products.
# Yielding subtree result Oral Care Products
# Subtree yielded choice Oral Care Products.
# Yielding subtree result Oral Care Products
# 	Item: 50 Pack Whiskey Party Favor Bag Aged to Perfection Waterproof Goodie Bags with Die Cut Handles Vintage Barrel Pattern Glossy Plastic Gift Bags for Adult Mature Man Birthday Party Decorations
# 	Short Desc: 50-Pack Waterproof Plastic Gift Bags with Handles, Vintage Barrel Design, Suitable for Adult Party Favors
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Stationery & Gift Wrapping Supplies
# Trying chosen subtree.
# Subtree yielded choice Stationery & Gift Wrapping Supplies.
# Yielding subtree result Stationery & Gift Wrapping Supplies
# 	Item: Baby Boys' Small Town Dude
# 	Short Desc: Baby Boy Clothing
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Baby Boys' Clothing & Shoes
# Trying chosen subtree.
# Subtree yielded choice Baby Boys' Clothing & Shoes.
# Yielding subtree result Baby Boys' Clothing & Shoes
# Subtree yielded choice Baby Boys' Clothing & Shoes.
# Yielding subtree result Baby Boys' Clothing & Shoes
# 	Item: VECELO Premium Velvet Suit Heavy Duty(30 Pack) -Non Slip & Space-Saving Clothes Hangers with 6 Finger Clips & Tie Rack Excellent for Men and Women(Rose)
# 	Short Desc: Clothes Hanger Set - Non-Slip, Space-Saving, 6 Finger Clips, Tie Rack (Rose)
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: OtterBox Fast Charge Premium Lightning to USB-C Cable, 2M - GLAMOUR BLACK
# 	Short Desc: Charging and Data Transfer Cable, Lightning to USB-C, 2M, Black
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: CHGCRAFT 8mm 49Pcs Natural Selenite Beads Stands Round Loose Beads Necklace Bead Loop for Jewelry Making, 1Strand 15.7inch, White
# 	Short Desc: Natural Selenite Beads - White, 49 Pcs, 8mm Diameter, Suitable for Jewelry Making
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Leisure & Hobby Supplies
# Trying chosen subtree.
# Entering Leisure & Hobby Supplies
# Trying Leisure & Hobby Supplies with 15 unexplored child nodes.
# Chose Craft Supplies & Materials
# Trying chosen subtree.
# Subtree yielded choice Craft Supplies & Materials.
# Yielding subtree result Craft Supplies & Materials
# Subtree yielded choice Craft Supplies & Materials.
# Yielding subtree result Craft Supplies & Materials
# 	Item: Niteangel Anti-Slide Hamster Wheel Platform - Fits for Niteangel Super-Silent Hamster Wheel | Acrylic Wheel | Wooden Wheel | Cloud Series Hamster Wheel (Medium)
# 	Short Desc: Anti-Slide Platform for Medium Hamster Wheel
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Pet & Aquarium Supplies
# Trying chosen subtree.
# Entering Pet & Aquarium Supplies
# Trying Pet & Aquarium Supplies with 5 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Men Women Cowboy hat Cotton Trucker Hats Adjustable Baseball Cap Hat
# 	Short Desc: Adjustable Cotton Baseball Cap - Unisex
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Personal & Home Essentials
# Trying chosen subtree.
# Entering Personal & Home Essentials
# Trying Personal & Home Essentials with 12 unexplored child nodes.
# Chose Gendered Apparel & Accessories
# Trying chosen subtree.
# Entering Gendered Apparel & Accessories
# Trying Gendered Apparel & Accessories with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Personal & Home Essentials with mask.
# Trying Personal & Home Essentials with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose Leisure & Hobby Supplies
# Trying chosen subtree.
# Entering Leisure & Hobby Supplies
# Trying Leisure & Hobby Supplies with 15 unexplored child nodes.
# Chose Sports & Outdoors
# Trying chosen subtree.
# Subtree yielded choice Sports & Outdoors.
# Yielding subtree result Sports & Outdoors
# Subtree yielded choice Sports & Outdoors.
# Yielding subtree result Sports & Outdoors
# 	Item: Yamaha MAR-KEYCH-AI-NB Marine Keychain, BLU; MARKEYCHAINB
# 	Short Desc: Marine themed blue keychain
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Leisure & Hobby Supplies
# Trying chosen subtree.
# Entering Leisure & Hobby Supplies
# Trying Leisure & Hobby Supplies with 15 unexplored child nodes.
# Chose Toys & Games
# Trying chosen subtree.
# Subtree yielded choice Toys & Games.
# Yielding subtree result Toys & Games
# Subtree yielded choice Toys & Games.
# Yielding subtree result Toys & Games
# 	Item: Pyrex 11 Cup Storage Plus Rectangular Dish With Plastic Cover Sold in packs of 2
# 	Short Desc: Food storage dish with lid, sold in packs of 2
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Packaging & Shipping Supplies
# Trying chosen subtree.
# Subtree yielded choice Packaging & Shipping Supplies.
# Yielding subtree result Packaging & Shipping Supplies
# 	Item: Feit BPQ500T3/CL/RS2 500W Heavy Duty Double Ended T3 Rough Service Halogen Bulb
# 	Short Desc: 500W Double-Ended Halogen Bulb
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Vehicle Maintenance & Powersports Equipment
# Trying chosen subtree.
# Entering Vehicle Maintenance & Powersports Equipment
# Trying Vehicle Maintenance & Powersports Equipment with 7 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Spider Choker Necklace Gothic Blood Red Cabochon Pendent Black Velvet Necklace Vampire Jewelry Gift for Women and Girls
# 	Short Desc: Gothic-style choker necklace with pendant on black velvet
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Personal & Home Essentials
# Trying chosen subtree.
# Entering Personal & Home Essentials
# Trying Personal & Home Essentials with 12 unexplored child nodes.
# Chose Girls' Jewelry
# Trying chosen subtree.
# Subtree yielded choice Girls' Jewelry.
# Yielding subtree result Girls' Jewelry
# Subtree yielded choice Girls' Jewelry.
# Yielding subtree result Girls' Jewelry
# 	Item: Cute Pumpkin Cartiage Earrings for Women Girls Sterling Silver Cubic Zirconia Vintage Lucky Princess Cinderella Tiny Small Studs Cartilage Hypoallergenic Holiday Birthday Jewelry Dainty Gifts for Daughter Niece
# 	Short Desc: Small sterling silver stud earrings with cubic zirconia, suitable for cartilage piercings, hypoallergenic
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Funko Pop! Jumbo: X-Men Sentinel with Wolverine Previews Exclusive Vinyl Figure
# 	Short Desc: Large collectible vinyl figure of X-Men characters: Sentinel with Wolverine
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Leisure & Hobby Supplies
# Trying chosen subtree.
# Entering Leisure & Hobby Supplies
# Trying Leisure & Hobby Supplies with 15 unexplored child nodes.
# Chose Toys & Games
# Trying chosen subtree.
# Subtree yielded choice Toys & Games.
# Yielding subtree result Toys & Games
# Subtree yielded choice Toys & Games.
# Yielding subtree result Toys & Games
# 	Item: Little Boys Polo Shirt Cute Stripe Plain Summer
# 	Short Desc: Boys' summer polo shirt with striped and plain designs
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Boys' Clothing
# Trying chosen subtree.
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# 	Item: Mens Swimming Trunks with Compression Liner 2 in 1 Quick Dry Beach Shorts with Pockets, Swim Trunks Men
# 	Short Desc: Men's Swim Trunks
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: 31in x 39in Large Format Heat Press Machine Manual Operation Hand Force Textile Thermo Transfer Heat Press Machine 220V 1P
# 	Short Desc: Large Heat Press Machine for Textile Printing
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Hunter x Hunter 13 Inch Sleeve Laptop Backpack, Padded Computer Bag for Commute or Travel, Multi, One Size
# 	Short Desc: Laptop Backpack, Padded Computer Bag for Commute/Travel
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Puppy Incubator - Puppy Incubator with Heating,Incubator for Newborn Puppies and Kittens,Kitten Incubator,Incubator for Puppies with Puppy Bed Mat 85L
# 	Short Desc: Newborn Animal Incubator with Heating
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Pet & Aquarium Supplies
# Trying chosen subtree.
# Entering Pet & Aquarium Supplies
# Trying Pet & Aquarium Supplies with 5 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Lee's Kritter Krawler Jumbo Exercise Ball, 10-Inch, Clear, All Breed Sizes
# 	Short Desc: Pet Exercise Ball, 10-Inch, Clear
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Pet & Aquarium Supplies
# Trying chosen subtree.
# Entering Pet & Aquarium Supplies
# Trying Pet & Aquarium Supplies with 5 unexplored child nodes.
# Chose Dog Supplies
# Trying chosen subtree.
# Subtree yielded choice Dog Supplies.
# Yielding subtree result Dog Supplies
# Subtree yielded choice Dog Supplies.
# Yielding subtree result Dog Supplies
# 	Item: Non-Slip Car Seat Covers with Storage Pocket,Black Leather Seat Covers for Comfortable Driving,Four Seasons Universal Car Seat Protector Fits 99% Cars SUVs Pickups
# 	Short Desc: Universal Car Seat Protector with Storage Pocket
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Vehicle Maintenance & Powersports Equipment
# Trying chosen subtree.
# Entering Vehicle Maintenance & Powersports Equipment
# Trying Vehicle Maintenance & Powersports Equipment with 7 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose Personal & Home Essentials
# Trying chosen subtree.
# Entering Personal & Home Essentials
# Trying Personal & Home Essentials with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 10 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: INNATE Response Formulas, Baby & Me Multivitamin, Prenatal and Postnatal Vitamin, Vegetarian, Non-GMO, 120 Tablets (60 Servings)
# 	Short Desc: Multivitamin tablet for prenatal and postnatal care
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Health & Personal Care Essentials
# Trying chosen subtree.
# Entering Health & Personal Care Essentials
# Trying Health & Personal Care Essentials with 9 unexplored child nodes.
# Chose Pregnancy & Maternity Products
# Trying chosen subtree.
# Subtree yielded choice Pregnancy & Maternity Products.
# Yielding subtree result Pregnancy & Maternity Products
# Subtree yielded choice Pregnancy & Maternity Products.
# Yielding subtree result Pregnancy & Maternity Products
# 	Item: Baby Toys 6 to 12 Months - Baby Rattles Activity Bell , Babies Music Rattles Toy with Multiple Music Song Lighting Modes, Infant Toys 6-12 Months Birthday and Christmas Boys Girls Gifts
# 	Short Desc: Infant activity toy with musical and light functions suitable for children aged 6-12 months.
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Kids' Development & Play Gear
# Trying chosen subtree.
# Entering Kids' Development & Play Gear
# Trying Kids' Development & Play Gear with 15 unexplored child nodes.
# Chose Baby Care Products
# Trying chosen subtree.
# Subtree yielded choice Baby Care Products.
# Yielding subtree result Baby Care Products
# Subtree yielded choice Baby Care Products.
# Yielding subtree result Baby Care Products
# Subtree yielded choice Baby Care Products.
# Yielding subtree result Baby Care Products
# 	Item: Wireless Charging Pad, 15W Max Fast Wireless Charger, Wireless Phone Charger for iPhone 14/14Plus/14 Pro/14 Pro Max/13/12/11/X/SE/8, Samsung Galaxy S22/S21/S20, Note20/10, AirPods Pro
# 	Short Desc: Wireless Charging Pad, up to 15W, compatible with various iPhone and Samsung models, charges AirPods Pro
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Personal & Home Essentials
# Trying chosen subtree.
# Entering Personal & Home Essentials
# Trying Personal & Home Essentials with 12 unexplored child nodes.
# Chose Tech Gadgets & Smart Home Solutions
# Trying chosen subtree.
# Entering Tech Gadgets & Smart Home Solutions
# Trying Tech Gadgets & Smart Home Solutions with 14 unexplored child nodes.
# Chose Consumer Tech & Entertainment
# Trying chosen subtree.
# Entering Consumer Tech & Entertainment
# Trying Consumer Tech & Entertainment with 13 unexplored child nodes.
# Chose Cell Phones & Accessories
# Trying chosen subtree.
# Subtree yielded choice Cell Phones & Accessories.
# Yielding subtree result Cell Phones & Accessories
# Subtree yielded choice Cell Phones & Accessories.
# Yielding subtree result Cell Phones & Accessories
# Subtree yielded choice Cell Phones & Accessories.
# Yielding subtree result Cell Phones & Accessories
# Subtree yielded choice Cell Phones & Accessories.
# Yielding subtree result Cell Phones & Accessories
# 	Item: 3 & 5 Gallon Water Jug Cap Replacement Non Spill Bottle Caps Anti Splash Peel Pack of 20
# 	Short Desc: Replacement water jug caps for 3 & 5 gallon bottles, non-spill, anti-splash, pack of 20
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Packaging & Shipping Supplies
# Trying chosen subtree.
# Subtree yielded choice Packaging & Shipping Supplies.
# Yielding subtree result Packaging & Shipping Supplies
# 	Item: Boys Swim Shorts
# 	Short Desc: Children's Swim Trunks
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Boys' Clothing
# Trying chosen subtree.
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# 	Item: Disney Pixar Cars Lightning McQueen Front Car Windshield Sun Shade (Gray)
# 	Short Desc: Car Windshield Sun Shade
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Vehicle Maintenance & Powersports Equipment
# Trying chosen subtree.
# Entering Vehicle Maintenance & Powersports Equipment
# Trying Vehicle Maintenance & Powersports Equipment with 7 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Bathroom Vessel Bowl Sink Faucet Matte Black Single Handle Lavatory Vanity Mixer Bar Tap with Pop Up Drain Combo Tall Spout Single Hole Deck Mount
# 	Short Desc: Bathroom sink faucet, single handle, matte finish, includes pop-up drain
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Personal & Home Essentials
# Trying chosen subtree.
# Entering Personal & Home Essentials
# Trying Personal & Home Essentials with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose Health & Personal Care Essentials
# Trying chosen subtree.
# Entering Health & Personal Care Essentials
# Trying Health & Personal Care Essentials with 9 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 10 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Men's Lansing Chelsea Steel Toe Pull on Comfortable Work Boots
# 	Short Desc: Men's Steel Toe Pull-On Work Boots
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Industrial Supplies & Equipment
# Trying chosen subtree.
# Entering Industrial Supplies & Equipment
# Trying Industrial Supplies & Equipment with 15 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Girls Pajamas Set Long Sleeve PJs 100% Cotton jammies
# 	Short Desc: Girls' Long Sleeve Cotton Pajama Set
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Girls' Clothing
# Trying chosen subtree.
# Subtree yielded choice Girls' Clothing.
# Yielding subtree result Girls' Clothing
# Subtree yielded choice Girls' Clothing.
# Yielding subtree result Girls' Clothing
# 	Item: 【Windows 11】 Intel NUC11PAHi5 Mini PC/HTPC,Mini Computer,Four-Core i5 1135G7 - Up to 4.2 GHz Turbo,NVMe SSD DDR4 RAM,WiFi 6,BT 5.2 Thunderbolt 3,8K Support,Quadruple Monitor Capable (8GB+512GB)
# 	Short Desc: Mini PC with i5 processor, 8GB RAM, 512GB SSD, supports WiFi 6 and up to four monitors.
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Danner Manufacturing, Inc. Supreme Oxy-Flow Low Volume Aquarium Air Pumps, AP-4 Aquarium Air Pump, 3.5-watt, No.06404,1 Count (Pack of 1),6404
# 	Short Desc: Aquarium Air Pump - Low Volume
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Pet & Aquarium Supplies
# Trying chosen subtree.
# Entering Pet & Aquarium Supplies
# Trying Pet & Aquarium Supplies with 5 unexplored child nodes.
# Chose Fish & Aquatic Pets
# Trying chosen subtree.
# Subtree yielded choice Fish & Aquatic Pets.
# Yielding subtree result Fish & Aquatic Pets
# Subtree yielded choice Fish & Aquatic Pets.
# Yielding subtree result Fish & Aquatic Pets
# 	Item: Haofy Armored Door Cord, Loop Power Transfer/Electrified Commercial Exit Doors/Door Wire Conduit/10mm Diameter/40cm Long Door Loop
# 	Short Desc: Armored Door Cord - Power Transfer Loop
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Vehicle Maintenance & Powersports Equipment
# Trying chosen subtree.
# Entering Vehicle Maintenance & Powersports Equipment
# Trying Vehicle Maintenance & Powersports Equipment with 7 unexplored child nodes.
# Chose RV Parts & Accessories
# Trying chosen subtree.
# Subtree yielded choice RV Parts & Accessories.
# Yielding subtree result RV Parts & Accessories
# Subtree yielded choice RV Parts & Accessories.
# Yielding subtree result RV Parts & Accessories
# 	Item: Abstract Grey White Navy Blue Large Wall Painting Canvas Wall Art Blue Marble Picture for Bedroom Wall Decor Modern Abstract Picture Canvas Artwork White and Blue Flower Art 16x24inchx3pcs No Frame
# 	Short Desc: Abstract canvas wall art set in blue and white tones, suitable for bedroom decor. Set includes 3 pieces, each measuring 16x24 inches without frames.
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# ...
# Trying chosen subtree.
# Entering Vehicle Maintenance & Powersports Equipment
# Trying Vehicle Maintenance & Powersports Equipment with 7 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: MOMCAYWEX Foldable Kids Sofa, Sherpa Teddy Bear Toddler Couch with Tri Folding Foam Cushions, Comfy Kids Couch for Kids Age 18 Months and Up
# 	Short Desc: Foldable kids sofa with foam cushions, suitable for toddlers aged 18 months and up.
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Kids' Development & Play Gear
# Trying chosen subtree.
# Entering Kids' Development & Play Gear
# Trying Kids' Development & Play Gear with 15 unexplored child nodes.
# Chose Kids' Home Store
# Trying chosen subtree.
# Subtree yielded choice Kids' Home Store.
# Yielding subtree result Kids' Home Store
# Subtree yielded choice Kids' Home Store.
# Yielding subtree result Kids' Home Store
# Subtree yielded choice Kids' Home Store.
# Yielding subtree result Kids' Home Store
# 	Item: Flex Double Pointed Needles (US 11/8 mm)
# 	Short Desc: Double Pointed Knitting Needles, Size 11/8 mm
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Leisure & Hobby Supplies
# Trying chosen subtree.
# Entering Leisure & Hobby Supplies
# Trying Leisure & Hobby Supplies with 15 unexplored child nodes.
# Chose Knitting & Crochet Supplies
# Trying chosen subtree.
# Subtree yielded choice Knitting & Crochet Supplies.
# Yielding subtree result Knitting & Crochet Supplies
# Subtree yielded choice Knitting & Crochet Supplies.
# Yielding subtree result Knitting & Crochet Supplies
# 	Item: Nelson Wood Shims, 8-inch Composite Bundle 2 Pack (Total 24 shims), Durable and Waterproof Shims, Perfect for Decks, Windows, Toilets, Outdoor and Indoor Leveling
# 	Short Desc: Composite Wood Shims - 8-inch, Pack of 2 (Total 24 shims), Durable & Waterproof
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Industrial Supplies & Equipment
# Trying chosen subtree.
# Entering Industrial Supplies & Equipment
# Trying Industrial Supplies & Equipment with 15 unexplored child nodes.
# Chose Hardware
# Trying chosen subtree.
# Subtree yielded choice Hardware.
# Yielding subtree result Hardware
# Subtree yielded choice Hardware.
# Yielding subtree result Hardware
# 	Item: Boys' Short Sleeve Pocket Logo Crew Neck T-Shirt, Soft, Comfortable, Relaxed Fit
# 	Short Desc: Boys' Short Sleeve Crew Neck T-Shirt with Pocket
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Boys' Clothing
# Trying chosen subtree.
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# 	Item: Rose Gold Tone Flower Cubic Zirconia Screwback Baby Girls Earrings Sterling Silver Post
# 	Short Desc: Baby Girls' Earrings with Cubic Zirconia Stones, Screwback Closure
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: 13" Large Baby Boy Girl Gift Bag for Baby Shower with Tissue Paper and Greeting Card (Yellow)
# 	Short Desc: Baby shower gift bag with accessories
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Stationery & Gift Wrapping Supplies
# Trying chosen subtree.
# Subtree yielded choice Stationery & Gift Wrapping Supplies.
# Yielding subtree result Stationery & Gift Wrapping Supplies
# 	Item: GREPSPUD 4Set 343-4009 Trailer Hub Caps, 3434009 6 Holes Aluminum Hub Cap for Trailer Axle, with 24Pcs Bolts, Side Pipe Plug, Gasket & Extra 4Pcs Blue Rubber Plugs, TR3434009 Semi Truck Hubcaps
# 	Short Desc: Set of 4 aluminum hub caps for trailer axle, includes bolts, side pipe plug, gasket, and extra rubber plugs
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Vehicle Maintenance & Powersports Equipment
# Trying chosen subtree.
# Entering Vehicle Maintenance & Powersports Equipment
# Trying Vehicle Maintenance & Powersports Equipment with 7 unexplored child nodes.
# Chose RV Parts & Accessories
# Trying chosen subtree.
# Subtree yielded choice RV Parts & Accessories.
# Yielding subtree result RV Parts & Accessories
# Subtree yielded choice RV Parts & Accessories.
# Yielding subtree result RV Parts & Accessories
# 	Item: Water-Based Thick Creamy White Lube, Unscented 8.3 fl. oz Smooth Slippery Lubricant for Couples, Made in USA | Package May Vary
# 	Short Desc: Thick Creamy White Unscented Lubricant, 8.3 fl. oz, for Couples
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Personal & Home Essentials
# Trying chosen subtree.
# Entering Personal & Home Essentials
# Trying Personal & Home Essentials with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: 3 Pack Starlink Ethernet Adapter for Wired External Network
# 	Short Desc: Ethernet network adapter - connects devices through wired connection
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Monster Jam 2022 Spin Master 1:64 Diecast Truck with Bonus Accessory: Arena Favorites Bad Company
# 	Short Desc: 1:64 Scale Die-Cast Truck Toy with Accessory
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Kids' Development & Play Gear
# Trying chosen subtree.
# Entering Kids' Development & Play Gear
# Trying Kids' Development & Play Gear with 15 unexplored child nodes.
# Chose Kids' Play Trucks
# Trying chosen subtree.
# Subtree yielded choice Kids' Play Trucks.
# Yielding subtree result Kids' Play Trucks
# Subtree yielded choice Kids' Play Trucks.
# Yielding subtree result Kids' Play Trucks
# Subtree yielded choice Kids' Play Trucks.
# Yielding subtree result Kids' Play Trucks
# 	Item: Dental Orthodontic separator placing pliers elastic separator placer pliers separator pliers by ARTMAN
# 	Short Desc: Dental orthodontic pliers for placing elastic separators
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Professional Dental Supplies
# Trying chosen subtree.
# Subtree yielded choice Professional Dental Supplies.
# Yielding subtree result Professional Dental Supplies
# 	Item: Police Officer Costume for Kids, Police Costume for Boys, Police Cop Costume-Shirt,Pants,Hat, Belt,Halloween Cosplay Party
# 	Short Desc: Children's Police Officer Costume - Includes Shirt, Pants, Hat, Belt
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Kids' Party Supplies
# Trying chosen subtree.
# Subtree yielded choice Kids' Party Supplies.
# Yielding subtree result Kids' Party Supplies
# Subtree yielded choice Kids' Party Supplies.
# Yielding subtree result Kids' Party Supplies
# 	Item: Leisure Backpack Can carry 14inche Computer Lightweight Boy School Backpack
# 	Short Desc: Laptop-compatible lightweight school backpack
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Gel Ball Blaster Toy, Automatic Splatter Ball Summer Water Toy with 50000+ Water Beads Straight Line Goggle, Outdoor Activities Team Shooting Game for Teens Boys Adults Ages 14+, Phantom Theme
# 	Short Desc: Automatic Water Bead Launcher Toy with Goggles
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Kids' Development & Play Gear
# Trying chosen subtree.
# Entering Kids' Development & Play Gear
# Trying Kids' Development & Play Gear with 15 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Children's Education & Apparel with mask.
# Trying Children's Education & Apparel with 7 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 11 unexplored child nodes.
# Chose Leisure & Hobby Supplies
# Trying chosen subtree.
# Entering Leisure & Hobby Supplies
# Trying Leisure & Hobby Supplies with 15 unexplored child nodes.
# Chose Children's Play & Learning Toys
# Trying chosen subtree.
# Entering Children's Play & Learning Toys
# Trying Children's Play & Learning Toys with 13 unexplored child nodes.
# Chose Novelty Toys & Amusements
# Trying chosen subtree.
# Subtree yielded choice Novelty Toys & Amusements.
# Yielding subtree result Novelty Toys & Amusements
# Subtree yielded choice Novelty Toys & Amusements.
# Yielding subtree result Novelty Toys & Amusements
# Subtree yielded choice Novelty Toys & Amusements.
# Yielding subtree result Novelty Toys & Amusements
# 	Item: Laser Tag Guns, Upgraded New Version Infrared Laser Tag Guns with Vests 4 Pack for Kids Adults Indoor Outdoor Group Activity Battle, Best Christmas and Birthday Gift for Kid Age 3+ (Version I)
# 	Short Desc: Laser tag set including guns and vests, suitable for both kids and adults, ideal for group play.
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Leisure & Hobby Supplies
# Trying chosen subtree.
# Entering Leisure & Hobby Supplies
# Trying Leisure & Hobby Supplies with 15 unexplored child nodes.
# Chose Toys & Games
# Trying chosen subtree.
# Subtree yielded choice Toys & Games.
# Yielding subtree result Toys & Games
# Subtree yielded choice Toys & Games.
# Yielding subtree result Toys & Games
# 	Item: Guinness 20oz Beer Glasses Twin Pack | Certified Official Merchandise | Ideal gift for Beer Lovers
# 	Short Desc: Set of 2 Official 20oz Beer Glasses
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Food Service Equipment & Supplies
# Trying chosen subtree.
# Subtree yielded choice Food Service Equipment & Supplies.
# Yielding subtree result Food Service Equipment & Supplies
# 	Item: Reusable Diapers, Washable and with Organic Bamboo insertions, for Kids and Babies Between 0-3 Years (Corazón)
# 	Short Desc: Reusable cloth diaper with organic bamboo insert for infants and toddlers (ages 0-3)
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Baby Boys' Clothing & Shoes
# Trying chosen subtree.
# Subtree yielded choice Baby Boys' Clothing & Shoes.
# Yielding subtree result Baby Boys' Clothing & Shoes
# Subtree yielded choice Baby Boys' Clothing & Shoes.
# Yielding subtree result Baby Boys' Clothing & Shoes
# 	Item: Boy's Slingback Flat Sandal
# 	Short Desc: Children's flat sandals with heel strap
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Boys' Clothing
# Trying chosen subtree.
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# 	Item: Women's 3 Pack Compression Shirts Long Sleeve Yoga Athletic Running T Shirt
# 	Short Desc: Women's Long Sleeve Compression Shirts for Athletic Use
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Personal & Home Essentials
# Trying chosen subtree.
# Entering Personal & Home Essentials
# Trying Personal & Home Essentials with 12 unexplored child nodes.
# Chose Gendered Apparel & Accessories
# Trying chosen subtree.
# Entering Gendered Apparel & Accessories
# Trying Gendered Apparel & Accessories with 11 unexplored child nodes.
# Chose Women's Clothing
# Trying chosen subtree.
# Subtree yielded choice Women's Clothing.
# Yielding subtree result Women's Clothing
# Subtree yielded choice Women's Clothing.
# Yielding subtree result Women's Clothing
# Subtree yielded choice Women's Clothing.
# Yielding subtree result Women's Clothing
# 	Item: THISWORKS Deep Sleep Breathe in, Natural Roll-On Sleep Aid and Tension Relief, 8 ml
# 	Short Desc: Natural Roll-On Sleep Aid and Tension Relief
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Health & Personal Care Essentials
# Trying chosen subtree.
# Entering Health & Personal Care Essentials
# Trying Health & Personal Care Essentials with 9 unexplored child nodes.
# Chose Personal Care & Health Products
# Trying chosen subtree.
# Entering Personal Care & Health Products
# Trying Personal Care & Health Products with 12 unexplored child nodes.
# Chose Wellness & Relaxation Products
# Trying chosen subtree.
# Subtree yielded choice Wellness & Relaxation Products.
# Yielding subtree result Wellness & Relaxation Products
# Subtree yielded choice Wellness & Relaxation Products.
# Yielding subtree result Wellness & Relaxation Products
# Subtree yielded choice Wellness & Relaxation Products.
# Yielding subtree result Wellness & Relaxation Products
# 	Item: 2D 1D 2.4G Wireless Bar Code Scanner Versatile 2 in 1 (Wireless+Wired) for Computers PC, UNIDEEPLY Automatic Barcode Reader Scanner 196 Feet Indoor Transmission Distance, QR PDF417 Scanning Gun, Black
# 	Short Desc: Wireless and wired 2-in-1 barcode and QR code scanner suitable for computers.
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Professional Dental Supplies
# Trying chosen subtree.
# Subtree yielded choice Professional Dental Supplies.
# Yielding subtree result Professional Dental Supplies
# 	Item: Men's Compression Style Pro Athletic Socks for Baseball, Softball, Football, and More
# 	Short Desc: Athletic Compression Socks - Multi-Sport Use
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Health & Personal Care Essentials
# Trying chosen subtree.
# Entering Health & Personal Care Essentials
# Trying Health & Personal Care Essentials with 9 unexplored child nodes.
# Chose Diet & Sports Nutrition
# Trying chosen subtree.
# Subtree yielded choice Diet & Sports Nutrition.
# Yielding subtree result Diet & Sports Nutrition
# Subtree yielded choice Diet & Sports Nutrition.
# Yielding subtree result Diet & Sports Nutrition
# 	Item: Harry Potter Toddler Kids I'm A Seeker Quidditch T-Shirt Tee
# 	Short Desc: Toddler Themed Quidditch T-Shirt
# Entering All Products
# Trying All Products with 12 unexplored child nodes.
# Chose Children's Education & Apparel
# Trying chosen subtree.
# Entering Children's Education & Apparel
# Trying Children's Education & Apparel with 8 unexplored child nodes.
# Chose Boys' Clothing
# Trying chosen subtree.
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# Subtree yielded choice Boys' Clothing.
# Yielding subtree result Boys' Clothing
# Saved classifications from tree_v4_improved.pkl to classification_results/classifications_v4_improved.csv
