# %%
import pickle
from model import Node, categorize_next, display_lazy_tree, format_node, format_time

# %%
import chardet

with open("amazon_products.csv", 'rb') as f:
    result = chardet.detect(f.read(8*1024*1024))
    print(result)
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
import pandas as pd
df = pd.read_csv("amazon_products.csv", encoding=result["encoding"])

# %%
df = df.sample(20000)
df.head()
# Out:
#               asin                                              title  \
# 494595  B0BCLYGL58  Tree House Pad & Paper | 27” x 17” Packing Pap...
# 379172  B07DNB11ZL  Long Wallets for Men Leather RFID Blocking Bif...
# 659430  B07PFF5GZD  Mens Analogue-Digital Quartz Watch with Resin ...
# 582438  B0BPMMDLDV  Godox XProII-S Wireless Flash Trigger for Sony...
# 561386  B09TS1BK51  Fashion Angels Laptop Beauty Pallete - Make-up...
#
#                                                    imgUrl  \
# 494595  https://m.media-amazon.com/images/I/7150xDXI0K...
# 379172  https://m.media-amazon.com/images/I/71mzFekYsj...
# 659430  https://m.media-amazon.com/images/I/71e6DwbvZ6...
# 582438  https://m.media-amazon.com/images/I/71OaPVoSnX...
# 561386  https://m.media-amazon.com/images/I/81BBOQj6BS...
#
#                                   productURL  stars  reviews   price  \
# 494595  https://www.amazon.com/dp/B0BCLYGL58    4.9        0   21.97
# 379172  https://www.amazon.com/dp/B07DNB11ZL    4.4        0   32.99
# 659430  https://www.amazon.com/dp/B07PFF5GZD    4.6        0  139.91
# 582438  https://www.amazon.com/dp/B0BPMMDLDV    4.7        0   89.00
# 561386  https://www.amazon.com/dp/B09TS1BK51    4.6        0   29.99
#
#         listPrice  category_id  isBestSeller  boughtInLastMonth
# 494595       0.00          160         False                  0
# 379172       0.00          112         False                 50
# 659430     148.89          113         False                  0
# 582438       0.00           79         False                  0
# 561386       0.00          270         False                  0

# %%
with open("./tree.pkl", "rb") as f:
    root = pickle.load(f)

# %%
from typing import Callable, Optional, Tuple
from langchain_core.language_models.chat_models import BaseChatModel

from model.data import TokenCounts

def classify(item_description: str, root: Node, create_llm: Callable[[], BaseChatModel]) -> Tuple[Optional[Node], TokenCounts]:
    def classify_recur(item_description: str, node: Node) -> Tuple[Optional[Node], TokenCounts]:
        if node.is_leaf():
            return node, TokenCounts()
        children = [*node.children]
        all_tokens = TokenCounts()
        print(f"Entering {node.condition}")
        while len(children) > 0:
            print(f"Trying {node.condition} with {len(children)} unexplored child nodes.")
            choice, tokens = categorize_next(item_description=item_description, nodes=children, create_llm=create_llm)
            print(f"Chose {choice.condition if choice else "None"}")
            all_tokens += tokens
            if choice is None:
                print(f"Retrying previous node with mask.")
                return (None, all_tokens)
            
            print(f"Trying chosen subtree.")
            result, tokens = classify_recur(item_description=item_description, node=choice)
            print(f"Subtree yielded choice {result.condition if result else "None"}.")
            all_tokens += tokens
            if result is not None:
                print(f"Yielding subtree result {result.condition}")
                return (result, all_tokens)
            
            print(f"Retrying {node.condition} with mask.")
            children.remove(choice)
            
        return None, all_tokens
            
    return classify_recur(item_description=item_description, node=root)

# %%
from langchain_ollama import ChatOllama
create_llm = lambda: ChatOllama(
    model="qwen2.5:32b",
    # temperature=0,
)

# %%
display_lazy_tree(root, max_initial_depth=3)
# Out:
# VBox(children=(FigureWidget({
#     'data': [{'branchvalues': 'total',
#               'ids': [2b7b01f4-e27f-4f6a-…

# %%
from pydantic import BaseModel, Field
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import HumanMessage
from langchain_community.callbacks import get_openai_callback


class Description(BaseModel):
    description: str = Field(description="The shortened description")

def prompt_tentative_description(item_description: str, create_llm: Callable[[], BaseChatModel]) -> Tuple[Description, TokenCounts]:
    template = """
    From the given e-commerce item description give a simplified short, generic description that would be useful in categorizing an item into product standardizations.
    From specific product names and branding provide a description that includes the true nature of the product.
    Use the given tool to provide your answer.
    
    {item}
    """.strip()
    
    prompt = ChatPromptTemplate.from_template(template)
    prompt = prompt.format(item=item_description)
    
    with get_openai_callback() as cb:
        llm = create_llm().with_structured_output(Description)
        response = llm.invoke([HumanMessage(prompt)])
        
    return response, TokenCounts(prompt=cb.prompt_tokens, completion=cb.completion_tokens, total=cb.total_tokens)

# %%
from ipywidgets import IntProgress, VBox, Label
from IPython.display import display
import time

def create_classification_sample(df: pd.DataFrame, root: Node) -> Tuple[pd.DataFrame, TokenCounts]:
    items: list[dict[str, any]] = []
    all_tokens = TokenCounts()

    total_rows = len(df)
    progress_bar = IntProgress(min=0, max=total_rows, description='Progress:', bar_style='info')
    label = Label(value=f"0/{total_rows} items processed")
    time_label = Label(value="Estimating time...")
    display(VBox([progress_bar, label, time_label]))

    processed_rows = 0
    start_time = time.time()

    for i, row in df.iterrows():
        short_desc, desc_tokens = prompt_tentative_description(item_description=row["title"], create_llm=create_llm)
        node, tokens = classify(item_description=short_desc.description, root=root, create_llm=create_llm)
        record = {
            "item": row["title"],
            "imputed_desc": short_desc.description,
            "classification": format_node(node) if node else "None"
        }
        items.append(record)
        all_tokens += tokens + desc_tokens

        processed_rows += 1
        elapsed_time = time.time() - start_time
        progress_bar.value = processed_rows
        label.value = f"{processed_rows}/{total_rows} items processed"
        estimated_total_time = elapsed_time / processed_rows * total_rows
        remaining_time = estimated_total_time - elapsed_time
        time_label.value = f"Estimated remaining time: {format_time(remaining_time)}"

    result = pd.DataFrame(items)
    return result, all_tokens

# %%
df_sample = df.sample(100)

args: list[dict[str,any]] = [
    {
        "model_file": "tree.pkl",
        "output_file": "classifications_cleaned_tree.csv"
    },
    {
        "model_file": "tree_improved.pkl",
        "output_file": "classifications_improved_tree.csv"
    }
]

output_dir = "classification_results"
tokens_output_file = "tokens.csv"

import os
import time

os.makedirs(output_dir, exist_ok=True)


tokens_dicts = []
for argset in args:
    start_time = time.time()
    with open(argset["model_file"], "rb") as f:
        root = pickle.load(f)
    
    out_df, tokens = create_classification_sample(df_sample, root)
    elapsed_time = time.time() - start_time
    tokens_dicts.append({
        **argset,
        "prompt": tokens.prompt,
        "completion": tokens.completion,
        "total": tokens.total,
        "elapsed_seconds": elapsed_time
    })
    out_df.to_csv(argset["output_file"])
    print(f"Saved classifications from {argset['model_file']} to {output_dir}/{argset['output_file']}")
    
tokens_df = pd.DataFrame(tokens_dicts)
tokens_df.to_csv(tokens_output_file)
# Out:
# VBox(children=(IntProgress(value=0, bar_style='info', description='Progress:'), Label(value='0/100 items proce…
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Industrial Machinery and Tools
# Trying chosen subtree.
# Entering Industrial Machinery and Tools
# Trying Industrial Machinery and Tools with 3 unexplored child nodes.
# Chose Tools and General Machinery
# Trying chosen subtree.
# Entering Tools and General Machinery
# Trying Tools and General Machinery with 4 unexplored child nodes.
# Chose Hand tools
# Trying chosen subtree.
# Entering Hand tools
# Trying Hand tools with 19 unexplored child nodes.
# Chose Measuring and layout tools
# Trying chosen subtree.
# Entering Measuring and layout tools
# Trying Measuring and layout tools with 3 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Hand tools with mask.
# Trying Hand tools with 18 unexplored child nodes.
# Chose Tool attachments and accessories
# Trying chosen subtree.
# Entering Tool attachments and accessories
# Trying Tool attachments and accessories with 16 unexplored child nodes.
# Chose Crimping and Forming Tools
# Trying chosen subtree.
# Entering Crimping and Forming Tools
# Trying Crimping and Forming Tools with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Tool attachments and accessories with mask.
# Trying Tool attachments and accessories with 15 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Hand tools with mask.
# Trying Hand tools with 17 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Tools and General Machinery with mask.
# Trying Tools and General Machinery with 3 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Industrial Machinery and Tools with mask.
# Trying Industrial Machinery and Tools with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 17 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Furniture and Furnishings
# Trying chosen subtree.
# Entering Furniture and Furnishings
# Trying Furniture and Furnishings with 5 unexplored child nodes.
# Chose Decorative adornments
# Trying chosen subtree.
# Entering Decorative adornments
# Trying Decorative adornments with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Furniture and Furnishings with mask.
# Trying Furniture and Furnishings with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 17 unexplored child nodes.
# Chose Paper Materials and Products
# Trying chosen subtree.
# Entering Paper Materials and Products
# Trying Paper Materials and Products with 3 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 16 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Apparel and Luggage and Personal Care Products
# Trying chosen subtree.
# Entering Apparel and Luggage and Personal Care Products
# Trying Apparel and Luggage and Personal Care Products with 5 unexplored child nodes.
# Chose Clothing
# Trying chosen subtree.
# Entering Clothing
# Trying Clothing with 18 unexplored child nodes.
# Chose Undergarments
# Trying chosen subtree.
# Entering Undergarments
# Trying Undergarments with 10 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Clothing with mask.
# Trying Clothing with 17 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Apparel and Luggage and Personal Care Products with mask.
# Trying Apparel and Luggage and Personal Care Products with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 17 unexplored child nodes.
# Chose Biological Materials and Supplies
# Trying chosen subtree.
# Entering Biological Materials and Supplies
# Trying Biological Materials and Supplies with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 16 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Infrastructure Components
# Trying chosen subtree.
# Entering Infrastructure Components
# Trying Infrastructure Components with 2 unexplored child nodes.
# Chose Structures and Building and Construction and Manufacturing Components and Supplies
# Trying chosen subtree.
# Entering Structures and Building and Construction and Manufacturing Components and Supplies
# Trying Structures and Building and Construction and Manufacturing Components and Supplies with 13 unexplored child nodes.
# Chose Exterior finishing materials
# Trying chosen subtree.
# Entering Exterior finishing materials
# Trying Exterior finishing materials with 7 unexplored child nodes.
# Chose Roofing accessories
# Trying chosen subtree.
# Entering Roofing accessories
# Trying Roofing accessories with 8 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Exterior finishing materials with mask.
# Trying Exterior finishing materials with 6 unexplored child nodes.
# Chose Finishing materials and products
# Trying chosen subtree.
# Entering Finishing materials and products
# Trying Finishing materials and products with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Exterior finishing materials with mask.
# Trying Exterior finishing materials with 5 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Structures and Building and Construction and Manufacturing Components and Supplies with mask.
# Trying Structures and Building and Construction and Manufacturing Components and Supplies with 12 unexplored child nodes.
# Chose Insulation
# Trying chosen subtree.
# Entering Insulation
# Trying Insulation with 3 unexplored child nodes.
# Chose Insulation sealing layers
# Trying chosen subtree.
# Entering Insulation sealing layers
# Trying Insulation sealing layers with 3 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Insulation with mask.
# Trying Insulation with 2 unexplored child nodes.
# Chose Thermal insulation
# Trying chosen subtree.
# Entering Thermal insulation
# Trying Thermal insulation with 11 unexplored child nodes.
# Chose Weather stripping
# Trying chosen subtree.
# Subtree yielded choice Weather stripping.
# Yielding subtree result Weather stripping
# Subtree yielded choice Weather stripping.
# Yielding subtree result Weather stripping
# Subtree yielded choice Weather stripping.
# Yielding subtree result Weather stripping
# Subtree yielded choice Weather stripping.
# Yielding subtree result Weather stripping
# Subtree yielded choice Weather stripping.
# Yielding subtree result Weather stripping
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Apparel and Luggage and Personal Care Products
# Trying chosen subtree.
# Entering Apparel and Luggage and Personal Care Products
# Trying Apparel and Luggage and Personal Care Products with 5 unexplored child nodes.
# Chose Luggage and handbags and packs and cases
# Trying chosen subtree.
# Entering Luggage and handbags and packs and cases
# Trying Luggage and handbags and packs and cases with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Apparel and Luggage and Personal Care Products with mask.
# Trying Apparel and Luggage and Personal Care Products with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 17 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Sports and Recreational Equipment and Supplies and Accessories
# Trying chosen subtree.
# Entering Sports and Recreational Equipment and Supplies and Accessories
# Trying Sports and Recreational Equipment and Supplies and Accessories with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 17 unexplored child nodes.
# Chose Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies
# Trying chosen subtree.
# Entering Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies
# Trying Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies with 5 unexplored child nodes.
# Chose Toys and games
# Trying chosen subtree.
# Entering Toys and games
# Trying Toys and games with 5 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies with mask.
# Trying Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 16 unexplored child nodes.
# Chose Telecommunications and Information Tech
# Trying chosen subtree.
# Entering Telecommunications and Information Tech
# Trying Telecommunications and Information Tech with 4 unexplored child nodes.
# Chose Domestic Appliances and Supplies and Consumer Electronic Products
# Trying chosen subtree.
# Entering Domestic Appliances and Supplies and Consumer Electronic Products
# Trying Domestic Appliances and Supplies and Consumer Electronic Products with 7 unexplored child nodes.
# Chose Consumer electronics
# Trying chosen subtree.
# Entering Consumer electronics
# Trying Consumer electronics with 2 unexplored child nodes.
# Chose Audio and visual equipment
# Trying chosen subtree.
# Entering Audio and visual equipment
# Trying Audio and visual equipment with 23 unexplored child nodes.
# Chose Visual Entertainment Equipment
# Trying chosen subtree.
# Entering Visual Entertainment Equipment
# Trying Visual Entertainment Equipment with 15 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Audio and visual equipment with mask.
# Trying Audio and visual equipment with 22 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Consumer electronics with mask.
# Trying Consumer electronics with 1 unexplored child nodes.
# Chose Audio visual equipment accessories
# Trying chosen subtree.
# Entering Audio visual equipment accessories
# Trying Audio visual equipment accessories with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Consumer electronics with mask.
# Subtree yielded choice None.
# Retrying Domestic Appliances and Supplies and Consumer Electronic Products with mask.
# Trying Domestic Appliances and Supplies and Consumer Electronic Products with 6 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Telecommunications and Information Tech with mask.
# Trying Telecommunications and Information Tech with 3 unexplored child nodes.
# Chose Electronic Components and Supplies
# Trying chosen subtree.
# Entering Electronic Components and Supplies
# Trying Electronic Components and Supplies with 6 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Telecommunications and Information Tech with mask.
# Trying Telecommunications and Information Tech with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 15 unexplored child nodes.
# Chose Infrastructure Components
# Trying chosen subtree.
# Entering Infrastructure Components
# Trying Infrastructure Components with 2 unexplored child nodes.
# Chose Electrical Systems and Lighting and Components and Accessories and Supplies
# Trying chosen subtree.
# Entering Electrical Systems and Lighting and Components and Accessories and Supplies
# Trying Electrical Systems and Lighting and Components and Accessories and Supplies with 4 unexplored child nodes.
# Chose Lighting Fixtures and Accessories
# Trying chosen subtree.
# Entering Lighting Fixtures and Accessories
# Trying Lighting Fixtures and Accessories with 12 unexplored child nodes.
# Chose Lighting accessories
# Trying chosen subtree.
# Entering Lighting accessories
# Trying Lighting accessories with 9 unexplored child nodes.
# Chose Safety and Protection Accessories
# Trying chosen subtree.
# Entering Safety and Protection Accessories
# Trying Safety and Protection Accessories with 5 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Lighting accessories with mask.
# Trying Lighting accessories with 8 unexplored child nodes.
# Chose Lighting Retrofit Solutions
# Trying chosen subtree.
# Entering Lighting Retrofit Solutions
# Trying Lighting Retrofit Solutions with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Lighting accessories with mask.
# Trying Lighting accessories with 7 unexplored child nodes.
# Chose Light boxes
# Trying chosen subtree.
# Subtree yielded choice Light boxes.
# Yielding subtree result Light boxes
# Subtree yielded choice Light boxes.
# Yielding subtree result Light boxes
# Subtree yielded choice Light boxes.
# Yielding subtree result Light boxes
# Subtree yielded choice Light boxes.
# Yielding subtree result Light boxes
# Subtree yielded choice Light boxes.
# Yielding subtree result Light boxes
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Apparel and Luggage and Personal Care Products
# Trying chosen subtree.
# Entering Apparel and Luggage and Personal Care Products
# Trying Apparel and Luggage and Personal Care Products with 5 unexplored child nodes.
# Chose Footwear
# Trying chosen subtree.
# Entering Footwear
# Trying Footwear with 7 unexplored child nodes.
# Chose Shoe accessories
# Trying chosen subtree.
# Entering Shoe accessories
# Trying Shoe accessories with 6 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Footwear with mask.
# Trying Footwear with 6 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Apparel and Luggage and Personal Care Products with mask.
# Trying Apparel and Luggage and Personal Care Products with 4 unexplored child nodes.
# Chose Clothing
# Trying chosen subtree.
# Entering Clothing
# Trying Clothing with 18 unexplored child nodes.
# Chose Hosiery
# Trying chosen subtree.
# Entering Hosiery
# Trying Hosiery with 4 unexplored child nodes.
# Chose Socks
# Trying chosen subtree.
# Subtree yielded choice Socks.
# Yielding subtree result Socks
# Subtree yielded choice Socks.
# Yielding subtree result Socks
# Subtree yielded choice Socks.
# Yielding subtree result Socks
# Subtree yielded choice Socks.
# Yielding subtree result Socks
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Apparel and Luggage and Personal Care Products
# Trying chosen subtree.
# Entering Apparel and Luggage and Personal Care Products
# Trying Apparel and Luggage and Personal Care Products with 5 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 17 unexplored child nodes.
# Chose Biological Materials and Supplies
# Trying chosen subtree.
# Entering Biological Materials and Supplies
# Trying Biological Materials and Supplies with 2 unexplored child nodes.
# Chose Live Plant and Animal Material and Accessories and Supplies
# Trying chosen subtree.
# Entering Live Plant and Animal Material and Accessories and Supplies
# Trying Live Plant and Animal Material and Accessories and Supplies with 14 unexplored child nodes.
# Chose Animal feed
# Trying chosen subtree.
# Entering Animal feed
# Trying Animal feed with 7 unexplored child nodes.
# Chose Dog and cat food
# Trying chosen subtree.
# Entering Dog and cat food
# Trying Dog and cat food with 6 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Animal feed with mask.
# Trying Animal feed with 6 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Live Plant and Animal Material and Accessories and Supplies with mask.
# Trying Live Plant and Animal Material and Accessories and Supplies with 13 unexplored child nodes.
# Chose Domestic pet treatments and accessories and equipment
# Trying chosen subtree.
# Entering Domestic pet treatments and accessories and equipment
# Trying Domestic pet treatments and accessories and equipment with 8 unexplored child nodes.
# Chose Pet food bowls or equipment
# Trying chosen subtree.
# Subtree yielded choice Pet food bowls or equipment.
# Yielding subtree result Pet food bowls or equipment
# Subtree yielded choice Pet food bowls or equipment.
# Yielding subtree result Pet food bowls or equipment
# Subtree yielded choice Pet food bowls or equipment.
# Yielding subtree result Pet food bowls or equipment
# Subtree yielded choice Pet food bowls or equipment.
# Yielding subtree result Pet food bowls or equipment
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies
# Trying chosen subtree.
# Entering Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies
# Trying Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies with 5 unexplored child nodes.
# Chose Developmental and professional teaching aids and materials and accessories and supplies
# Trying chosen subtree.
# Entering Developmental and professional teaching aids and materials and accessories and supplies
# Trying Developmental and professional teaching aids and materials and accessories and supplies with 21 unexplored child nodes.
# Chose Geography and map skills resources and accessories
# Trying chosen subtree.
# Entering Geography and map skills resources and accessories
# Trying Geography and map skills resources and accessories with 10 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Developmental and professional teaching aids and materials and accessories and supplies with mask.
# Trying Developmental and professional teaching aids and materials and accessories and supplies with 20 unexplored child nodes.
# Chose Political science
# Trying chosen subtree.
# Entering Political science
# Trying Political science with 4 unexplored child nodes.
# Chose Government activity or resource books
# Trying chosen subtree.
# Subtree yielded choice Government activity or resource books.
# Yielding subtree result Government activity or resource books
# Subtree yielded choice Government activity or resource books.
# Yielding subtree result Government activity or resource books
# Subtree yielded choice Government activity or resource books.
# Yielding subtree result Government activity or resource books
# Subtree yielded choice Government activity or resource books.
# Yielding subtree result Government activity or resource books
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Infrastructure Components
# Trying chosen subtree.
# Entering Infrastructure Components
# Trying Infrastructure Components with 2 unexplored child nodes.
# Chose Structures and Building and Construction and Manufacturing Components and Supplies
# Trying chosen subtree.
# Entering Structures and Building and Construction and Manufacturing Components and Supplies
# Trying Structures and Building and Construction and Manufacturing Components and Supplies with 13 unexplored child nodes.
# Chose Doors and windows and glass
# Trying chosen subtree.
# Entering Doors and windows and glass
# Trying Doors and windows and glass with 7 unexplored child nodes.
# Chose Doors
# Trying chosen subtree.
# Entering Doors
# Trying Doors with 10 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Doors and windows and glass with mask.
# Trying Doors and windows and glass with 6 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Structures and Building and Construction and Manufacturing Components and Supplies with mask.
# Trying Structures and Building and Construction and Manufacturing Components and Supplies with 12 unexplored child nodes.
# Chose Interior finishing materials
# Trying chosen subtree.
# Entering Interior finishing materials
# Trying Interior finishing materials with 10 unexplored child nodes.
# Chose Flooring
# Trying chosen subtree.
# Entering Flooring
# Trying Flooring with 19 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Interior finishing materials with mask.
# Trying Interior finishing materials with 9 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Structures and Building and Construction and Manufacturing Components and Supplies with mask.
# Trying Structures and Building and Construction and Manufacturing Components and Supplies with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Infrastructure Components with mask.
# Trying Infrastructure Components with 1 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 17 unexplored child nodes.
# Chose Safety and Security Equipment
# Trying chosen subtree.
# Entering Safety and Security Equipment
# Trying Safety and Security Equipment with 4 unexplored child nodes.
# Chose Defense and Law Enforcement and Security and Safety Equipment and Supplies
# Trying chosen subtree.
# Entering Defense and Law Enforcement and Security and Safety Equipment and Supplies
# Trying Defense and Law Enforcement and Security and Safety Equipment and Supplies with 13 unexplored child nodes.
# Chose Public safety and control
# Trying chosen subtree.
# Entering Public safety and control
# Trying Public safety and control with 3 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Defense and Law Enforcement and Security and Safety Equipment and Supplies with mask.
# Trying Defense and Law Enforcement and Security and Safety Equipment and Supplies with 12 unexplored child nodes.
# Chose Security surveillance and detection
# Trying chosen subtree.
# Entering Security surveillance and detection
# Trying Security surveillance and detection with 3 unexplored child nodes.
# Chose Locks and security hardware and accessories
# Trying chosen subtree.
# Entering Locks and security hardware and accessories
# Trying Locks and security hardware and accessories with 25 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Security surveillance and detection with mask.
# Trying Security surveillance and detection with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Defense and Law Enforcement and Security and Safety Equipment and Supplies with mask.
# Trying Defense and Law Enforcement and Security and Safety Equipment and Supplies with 11 unexplored child nodes.
# Chose Personal safety and protection
# Trying chosen subtree.
# Entering Personal safety and protection
# Trying Personal safety and protection with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Defense and Law Enforcement and Security and Safety Equipment and Supplies with mask.
# Trying Defense and Law Enforcement and Security and Safety Equipment and Supplies with 10 unexplored child nodes.
# Chose Workplace safety equipment and supplies and training materials
# Trying chosen subtree.
# Entering Workplace safety equipment and supplies and training materials
# Trying Workplace safety equipment and supplies and training materials with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Defense and Law Enforcement and Security and Safety Equipment and Supplies with mask.
# Trying Defense and Law Enforcement and Security and Safety Equipment and Supplies with 9 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Safety and Security Equipment with mask.
# Trying Safety and Security Equipment with 3 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 16 unexplored child nodes.
# Chose Furniture and Furnishings
# Trying chosen subtree.
# Entering Furniture and Furnishings
# Trying Furniture and Furnishings with 5 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 15 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Apparel and Luggage and Personal Care Products
# Trying chosen subtree.
# Entering Apparel and Luggage and Personal Care Products
# Trying Apparel and Luggage and Personal Care Products with 5 unexplored child nodes.
# Chose Personal care products
# Trying chosen subtree.
# Entering Personal care products
# Trying Personal care products with 4 unexplored child nodes.
# Chose Dental
# Trying chosen subtree.
# Entering Dental
# Trying Dental with 10 unexplored child nodes.
# Chose Toothpaste
# Trying chosen subtree.
# Subtree yielded choice Toothpaste.
# Yielding subtree result Toothpaste
# Subtree yielded choice Toothpaste.
# Yielding subtree result Toothpaste
# Subtree yielded choice Toothpaste.
# Yielding subtree result Toothpaste
# Subtree yielded choice Toothpaste.
# Yielding subtree result Toothpaste
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies
# Trying chosen subtree.
# Entering Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies
# Trying Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies with 5 unexplored child nodes.
# Chose Classroom decoratives and supplies
# Trying chosen subtree.
# Entering Classroom decoratives and supplies
# Trying Classroom decoratives and supplies with 5 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies with mask.
# Trying Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 17 unexplored child nodes.
# Chose Biological Materials and Supplies
# Trying chosen subtree.
# Entering Biological Materials and Supplies
# Trying Biological Materials and Supplies with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 16 unexplored child nodes.
# Chose Infrastructure Components
# Trying chosen subtree.
# Entering Infrastructure Components
# Trying Infrastructure Components with 2 unexplored child nodes.
# Chose Structures and Building and Construction and Manufacturing Components and Supplies
# Trying chosen subtree.
# Entering Structures and Building and Construction and Manufacturing Components and Supplies
# Trying Structures and Building and Construction and Manufacturing Components and Supplies with 13 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Infrastructure Components with mask.
# Trying Infrastructure Components with 1 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 15 unexplored child nodes.
# Chose Sports and Recreational Equipment and Supplies and Accessories
# Trying chosen subtree.
# Entering Sports and Recreational Equipment and Supplies and Accessories
# Trying Sports and Recreational Equipment and Supplies and Accessories with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 14 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Industrial Machinery and Tools
# Trying chosen subtree.
# Entering Industrial Machinery and Tools
# Trying Industrial Machinery and Tools with 3 unexplored child nodes.
# Chose Tools and General Machinery
# Trying chosen subtree.
# Entering Tools and General Machinery
# Trying Tools and General Machinery with 4 unexplored child nodes.
# Chose Hand tools
# Trying chosen subtree.
# Entering Hand tools
# Trying Hand tools with 19 unexplored child nodes.
# Chose Measuring and layout tools
# Trying chosen subtree.
# Entering Measuring and layout tools
# Trying Measuring and layout tools with 3 unexplored child nodes.
# Chose Alignment and Layout Tools
# Trying chosen subtree.
# Entering Alignment and Layout Tools
# Trying Alignment and Layout Tools with 11 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Measuring and layout tools with mask.
# Trying Measuring and layout tools with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Hand tools with mask.
# Trying Hand tools with 18 unexplored child nodes.
# Chose Wrenches and drivers
# Trying chosen subtree.
# Entering Wrenches and drivers
# Trying Wrenches and drivers with 8 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Hand tools with mask.
# Trying Hand tools with 17 unexplored child nodes.
# Chose Tool attachments and accessories
# Trying chosen subtree.
# Entering Tool attachments and accessories
# Trying Tool attachments and accessories with 16 unexplored child nodes.
# Chose Tool template sets
# Trying chosen subtree.
# Subtree yielded choice Tool template sets.
# Yielding subtree result Tool template sets
# Subtree yielded choice Tool template sets.
# Yielding subtree result Tool template sets
# Subtree yielded choice Tool template sets.
# Yielding subtree result Tool template sets
# Subtree yielded choice Tool template sets.
# Yielding subtree result Tool template sets
# Subtree yielded choice Tool template sets.
# Yielding subtree result Tool template sets
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Apparel and Luggage and Personal Care Products
# Trying chosen subtree.
# Entering Apparel and Luggage and Personal Care Products
# Trying Apparel and Luggage and Personal Care Products with 5 unexplored child nodes.
# Chose Clothing
# Trying chosen subtree.
# Entering Clothing
# Trying Clothing with 18 unexplored child nodes.
# Chose Athletic wear
# Trying chosen subtree.
# Entering Athletic wear
# Trying Athletic wear with 4 unexplored child nodes.
# Chose Womens athletic wear
# Trying chosen subtree.
# Subtree yielded choice Womens athletic wear.
# Yielding subtree result Womens athletic wear
# Subtree yielded choice Womens athletic wear.
# Yielding subtree result Womens athletic wear
# Subtree yielded choice Womens athletic wear.
# Yielding subtree result Womens athletic wear
# Subtree yielded choice Womens athletic wear.
# Yielding subtree result Womens athletic wear
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies
# Trying chosen subtree.
# Entering Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies
# Trying Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies with 5 unexplored child nodes.
# Chose Toys and games
# Trying chosen subtree.
# Entering Toys and games
# Trying Toys and games with 5 unexplored child nodes.
# Chose Toys
# Trying chosen subtree.
# Entering Toys
# Trying Toys with 13 unexplored child nodes.
# Chose Imaginative Playsets
# Trying chosen subtree.
# Entering Imaginative Playsets
# Trying Imaginative Playsets with 5 unexplored child nodes.
# Chose Dolls
# Trying chosen subtree.
# Subtree yielded choice Dolls.
# Yielding subtree result Dolls
# Subtree yielded choice Dolls.
# Yielding subtree result Dolls
# Subtree yielded choice Dolls.
# Yielding subtree result Dolls
# Subtree yielded choice Dolls.
# Yielding subtree result Dolls
# Subtree yielded choice Dolls.
# Yielding subtree result Dolls
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Industrial Machinery and Tools
# Trying chosen subtree.
# Entering Industrial Machinery and Tools
# Trying Industrial Machinery and Tools with 3 unexplored child nodes.
# Chose Tools and General Machinery
# Trying chosen subtree.
# Entering Tools and General Machinery
# Trying Tools and General Machinery with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Industrial Machinery and Tools with mask.
# Trying Industrial Machinery and Tools with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 17 unexplored child nodes.
# Chose Manufacturing and Processing Systems
# Trying chosen subtree.
# Entering Manufacturing and Processing Systems
# Trying Manufacturing and Processing Systems with 7 unexplored child nodes.
# Chose Manufacturing Components and Supplies
# Trying chosen subtree.
# Entering Manufacturing Components and Supplies
# Trying Manufacturing Components and Supplies with 7 unexplored child nodes.
# Chose Material Processing
# Trying chosen subtree.
# Entering Material Processing
# Trying Material Processing with 8 unexplored child nodes.
# Chose Grinding and polishing and smoothing materials
# Trying chosen subtree.
# Entering Grinding and polishing and smoothing materials
# Trying Grinding and polishing and smoothing materials with 2 unexplored child nodes.
# Chose Abrasive wheels
# Trying chosen subtree.
# Entering Abrasive wheels
# Trying Abrasive wheels with 3 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Grinding and polishing and smoothing materials with mask.
# Trying Grinding and polishing and smoothing materials with 1 unexplored child nodes.
# Chose Abrasives and abrasive media
# Trying chosen subtree.
# Entering Abrasives and abrasive media
# Trying Abrasives and abrasive media with 20 unexplored child nodes.
# Chose Abrasive discs
# Trying chosen subtree.
# Subtree yielded choice Abrasive discs.
# Yielding subtree result Abrasive discs
# Subtree yielded choice Abrasive discs.
# Yielding subtree result Abrasive discs
# Subtree yielded choice Abrasive discs.
# Yielding subtree result Abrasive discs
# Subtree yielded choice Abrasive discs.
# Yielding subtree result Abrasive discs
# Subtree yielded choice Abrasive discs.
# Yielding subtree result Abrasive discs
# Subtree yielded choice Abrasive discs.
# Yielding subtree result Abrasive discs
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Telecommunications and Information Tech
# Trying chosen subtree.
# Entering Telecommunications and Information Tech
# Trying Telecommunications and Information Tech with 4 unexplored child nodes.
# Chose Electronic Components and Supplies
# Trying chosen subtree.
# Entering Electronic Components and Supplies
# Trying Electronic Components and Supplies with 6 unexplored child nodes.
# Chose Automation control devices and components and accessories
# Trying chosen subtree.
# Entering Automation control devices and components and accessories
# Trying Automation control devices and components and accessories with 6 unexplored child nodes.
# Chose Automation control connectivity devices
# Trying chosen subtree.
# Entering Automation control connectivity devices
# Trying Automation control connectivity devices with 10 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Automation control devices and components and accessories with mask.
# Trying Automation control devices and components and accessories with 5 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Electronic Components and Supplies with mask.
# Trying Electronic Components and Supplies with 5 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Telecommunications and Information Tech with mask.
# Trying Telecommunications and Information Tech with 3 unexplored child nodes.
# Chose Information Technology Broadcasting and Telecommunications
# Trying chosen subtree.
# Entering Information Technology Broadcasting and Telecommunications
# Trying Information Technology Broadcasting and Telecommunications with 5 unexplored child nodes.
# Chose Data Voice or Multimedia Network Equipment or Platforms and Accessories
# Trying chosen subtree.
# Entering Data Voice or Multimedia Network Equipment or Platforms and Accessories
# Trying Data Voice or Multimedia Network Equipment or Platforms and Accessories with 13 unexplored child nodes.
# Chose Datacom and network connectivity installation devices and equipment
# Trying chosen subtree.
# Entering Datacom and network connectivity installation devices and equipment
# Trying Datacom and network connectivity installation devices and equipment with 5 unexplored child nodes.
# Chose Network Connectivity Equipment
# Trying chosen subtree.
# Entering Network Connectivity Equipment
# Trying Network Connectivity Equipment with 6 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Datacom and network connectivity installation devices and equipment with mask.
# Trying Datacom and network connectivity installation devices and equipment with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Data Voice or Multimedia Network Equipment or Platforms and Accessories with mask.
# Trying Data Voice or Multimedia Network Equipment or Platforms and Accessories with 12 unexplored child nodes.
# Chose Network service equipment
# Trying chosen subtree.
# Entering Network service equipment
# Trying Network service equipment with 12 unexplored child nodes.
# Chose Network Access Devices
# Trying chosen subtree.
# Entering Network Access Devices
# Trying Network Access Devices with 16 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Network service equipment with mask.
# Trying Network service equipment with 11 unexplored child nodes.
# Chose Routing and Switching Equipment
# Trying chosen subtree.
# Entering Routing and Switching Equipment
# Trying Routing and Switching Equipment with 9 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Network service equipment with mask.
# Trying Network service equipment with 10 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Data Voice or Multimedia Network Equipment or Platforms and Accessories with mask.
# Trying Data Voice or Multimedia Network Equipment or Platforms and Accessories with 11 unexplored child nodes.
# Chose Fixed network equipment and components
# Trying chosen subtree.
# Entering Fixed network equipment and components
# Trying Fixed network equipment and components with 7 unexplored child nodes.
# Chose Signal Processing and Management Devices
# Trying chosen subtree.
# Entering Signal Processing and Management Devices
# Trying Signal Processing and Management Devices with 5 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Fixed network equipment and components with mask.
# Trying Fixed network equipment and components with 6 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Data Voice or Multimedia Network Equipment or Platforms and Accessories with mask.
# Trying Data Voice or Multimedia Network Equipment or Platforms and Accessories with 10 unexplored child nodes.
# Chose Telephony equipment accessories
# Trying chosen subtree.
# Entering Telephony equipment accessories
# Trying Telephony equipment accessories with 3 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Data Voice or Multimedia Network Equipment or Platforms and Accessories with mask.
# Trying Data Voice or Multimedia Network Equipment or Platforms and Accessories with 9 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Information Technology Broadcasting and Telecommunications with mask.
# Trying Information Technology Broadcasting and Telecommunications with 4 unexplored child nodes.
# Chose Components for information technology or broadcasting or telecommunications
# Trying chosen subtree.
# Entering Components for information technology or broadcasting or telecommunications
# Trying Components for information technology or broadcasting or telecommunications with 8 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Information Technology Broadcasting and Telecommunications with mask.
# Trying Information Technology Broadcasting and Telecommunications with 3 unexplored child nodes.
# Chose Communications Devices and Accessories
# Trying chosen subtree.
# Entering Communications Devices and Accessories
# Trying Communications Devices and Accessories with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Information Technology Broadcasting and Telecommunications with mask.
# Trying Information Technology Broadcasting and Telecommunications with 2 unexplored child nodes.
# Chose Computer Equipment and Accessories
# Trying chosen subtree.
# Entering Computer Equipment and Accessories
# Trying Computer Equipment and Accessories with 8 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Information Technology Broadcasting and Telecommunications with mask.
# Trying Information Technology Broadcasting and Telecommunications with 1 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Telecommunications and Information Tech with mask.
# Trying Telecommunications and Information Tech with 2 unexplored child nodes.
# Chose Domestic Appliances and Supplies and Consumer Electronic Products
# Trying chosen subtree.
# Entering Domestic Appliances and Supplies and Consumer Electronic Products
# Trying Domestic Appliances and Supplies and Consumer Electronic Products with 7 unexplored child nodes.
# Chose Consumer electronics
# Trying chosen subtree.
# Entering Consumer electronics
# Trying Consumer electronics with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Domestic Appliances and Supplies and Consumer Electronic Products with mask.
# Trying Domestic Appliances and Supplies and Consumer Electronic Products with 6 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Telecommunications and Information Tech with mask.
# Trying Telecommunications and Information Tech with 1 unexplored child nodes.
# Chose Office Equipment and Accessories and Supplies
# Trying chosen subtree.
# Entering Office Equipment and Accessories and Supplies
# Trying Office Equipment and Accessories and Supplies with 3 unexplored child nodes.
# Chose Office machines and their supplies and accessories
# Trying chosen subtree.
# Entering Office machines and their supplies and accessories
# Trying Office machines and their supplies and accessories with 19 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Office Equipment and Accessories and Supplies with mask.
# Trying Office Equipment and Accessories and Supplies with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Telecommunications and Information Tech with mask.
# Subtree yielded choice None.
# Retrying None with mask.
# Trying None with 17 unexplored child nodes.
# Chose Infrastructure Components
# Trying chosen subtree.
# Entering Infrastructure Components
# Trying Infrastructure Components with 2 unexplored child nodes.
# Chose Electrical Systems and Lighting and Components and Accessories and Supplies
# Trying chosen subtree.
# Entering Electrical Systems and Lighting and Components and Accessories and Supplies
# Trying Electrical Systems and Lighting and Components and Accessories and Supplies with 4 unexplored child nodes.
# Chose Electrical equipment and components and supplies
# Trying chosen subtree.
# Entering Electrical equipment and components and supplies
# Trying Electrical equipment and components and supplies with 13 unexplored child nodes.
# Chose Power conditioning equipment
# Trying chosen subtree.
# Entering Power conditioning equipment
# Trying Power conditioning equipment with 10 unexplored child nodes.
# Chose Power Conversion Devices
# Trying chosen subtree.
# Entering Power Conversion Devices
# Trying Power Conversion Devices with 10 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Power conditioning equipment with mask.
# Trying Power conditioning equipment with 9 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Electrical equipment and components and supplies with mask.
# Trying Electrical equipment and components and supplies with 12 unexplored child nodes.
# Chose Intelligent Building Installations IBI
# Trying chosen subtree.
# Entering Intelligent Building Installations IBI
# Trying Intelligent Building Installations IBI with 3 unexplored child nodes.
# Chose Controlling units or devices
# Trying chosen subtree.
# Subtree yielded choice Controlling units or devices.
# Yielding subtree result Controlling units or devices
# Subtree yielded choice Controlling units or devices.
# Yielding subtree result Controlling units or devices
# Subtree yielded choice Controlling units or devices.
# Yielding subtree result Controlling units or devices
# Subtree yielded choice Controlling units or devices.
# Yielding subtree result Controlling units or devices
# Subtree yielded choice Controlling units or devices.
# Yielding subtree result Controlling units or devices
# Entering None
# Trying None with 18 unexplored child nodes.
# Chose Apparel and Luggage and Personal Care Products
# Trying chosen subtree.
# Entering Apparel and Luggage and Personal Care Products
# Trying Apparel and Luggage and Personal Care Products with 5 unexplored child nodes.
# Chose Clothing
# Trying chosen subtree.
# Entering Clothing
# Trying Clothing with 18 unexplored child nodes.
# Chose Coats and jackets
# Trying chosen subtree.
# Entering Coats and jackets
# ...
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying FashionTravelPersonalEssentials with mask.
# Trying FashionTravelPersonalEssentials with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying BusinessAndIndustrialSolutions with mask.
# Trying BusinessAndIndustrialSolutions with 16 unexplored child nodes.
# Chose PrintingAVImagingSupplies
# Trying chosen subtree.
# Entering PrintingAVImagingSupplies
# Trying PrintingAVImagingSupplies with 5 unexplored child nodes.
# Chose Imaging & Camera Gear with Film & Microfilm Supplies
# Trying chosen subtree.
# Entering Imaging & Camera Gear with Film & Microfilm Supplies
# Trying Imaging & Camera Gear with Film & Microfilm Supplies with 4 unexplored child nodes.
# Chose Camera Equipment &配件
# Trying chosen subtree.
# Entering Camera Equipment &配件
# Trying Camera Equipment &配件 with 12 unexplored child nodes.
# Chose Camera Stabilization & Accessories
# Trying chosen subtree.
# Entering Camera Stabilization & Accessories
# Trying Camera Stabilization & Accessories with 8 unexplored child nodes.
# Chose Camera blocks or holders
# Trying chosen subtree.
# Subtree yielded choice Camera blocks or holders.
# Yielding subtree result Camera blocks or holders
# Subtree yielded choice Camera blocks or holders.
# Yielding subtree result Camera blocks or holders
# Subtree yielded choice Camera blocks or holders.
# Yielding subtree result Camera blocks or holders
# Subtree yielded choice Camera blocks or holders.
# Yielding subtree result Camera blocks or holders
# Subtree yielded choice Camera blocks or holders.
# Yielding subtree result Camera blocks or holders
# Entering BusinessAndIndustrialSolutions
# Trying BusinessAndIndustrialSolutions with 18 unexplored child nodes.
# Chose Electronics & Telecom Hardware Solutions
# Trying chosen subtree.
# Entering Electronics & Telecom Hardware Solutions
# Trying Electronics & Telecom Hardware Solutions with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying BusinessAndIndustrialSolutions with mask.
# Trying BusinessAndIndustrialSolutions with 17 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Entering BusinessAndIndustrialSolutions
# Trying BusinessAndIndustrialSolutions with 18 unexplored child nodes.
# Chose Oilfield Mining & Industrial Equipment
# Trying chosen subtree.
# Entering Oilfield Mining & Industrial Equipment
# Trying Oilfield Mining & Industrial Equipment with 3 unexplored child nodes.
# Chose Industrial Equipment and Tooling
# Trying chosen subtree.
# Entering Industrial Equipment and Tooling
# Trying Industrial Equipment and Tooling with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Oilfield Mining & Industrial Equipment with mask.
# Trying Oilfield Mining & Industrial Equipment with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying BusinessAndIndustrialSolutions with mask.
# Trying BusinessAndIndustrialSolutions with 17 unexplored child nodes.
# Chose Construction & Electrical Systems
# Trying chosen subtree.
# Entering Construction & Electrical Systems
# Trying Construction & Electrical Systems with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying BusinessAndIndustrialSolutions with mask.
# Trying BusinessAndIndustrialSolutions with 16 unexplored child nodes.
# Chose Commercial & Educational Furniture & Decor
# Trying chosen subtree.
# Entering Commercial & Educational Furniture & Decor
# Trying Commercial & Educational Furniture & Decor with 5 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying BusinessAndIndustrialSolutions with mask.
# Trying BusinessAndIndustrialSolutions with 15 unexplored child nodes.
# Chose Electronics & Telecom Hardware Solutions
# Trying chosen subtree.
# Entering Electronics & Telecom Hardware Solutions
# Trying Electronics & Telecom Hardware Solutions with 4 unexplored child nodes.
# Chose Home Furnishings & Appliances
# Trying chosen subtree.
# Entering Home Furnishings & Appliances
# Trying Home Furnishings & Appliances with 7 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Electronics & Telecom Hardware Solutions with mask.
# Trying Electronics & Telecom Hardware Solutions with 3 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying BusinessAndIndustrialSolutions with mask.
# Trying BusinessAndIndustrialSolutions with 14 unexplored child nodes.
# Chose Outdoor_Adventure_and_Sports_Equipment
# Trying chosen subtree.
# Entering Outdoor_Adventure_and_Sports_Equipment
# Trying Outdoor_Adventure_and_Sports_Equipment with 12 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying BusinessAndIndustrialSolutions with mask.
# Trying BusinessAndIndustrialSolutions with 13 unexplored child nodes.
# Chose Industrial Processing & Equipment Solutions
# Trying chosen subtree.
# Entering Industrial Processing & Equipment Solutions
# Trying Industrial Processing & Equipment Solutions with 7 unexplored child nodes.
# Chose Industrial Manufacturing Parts and Materials
# Trying chosen subtree.
# Entering Industrial Manufacturing Parts and Materials
# Trying Industrial Manufacturing Parts and Materials with 7 unexplored child nodes.
# Chose Sealants, Coatings, and Gaskets
# Trying chosen subtree.
# Entering Sealants, Coatings, and Gaskets
# Trying Sealants, Coatings, and Gaskets with 5 unexplored child nodes.
# Chose Seal & Protect Components
# Trying chosen subtree.
# Entering Seal & Protect Components
# Trying Seal & Protect Components with 2 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Sealants, Coatings, and Gaskets with mask.
# Trying Sealants, Coatings, and Gaskets with 4 unexplored child nodes.
# Chose BondingTapesAndCoatings
# Trying chosen subtree.
# Entering BondingTapesAndCoatings
# Trying BondingTapesAndCoatings with 3 unexplored child nodes.
# Chose Adhesion & Protection Tapes
# Trying chosen subtree.
# Entering Adhesion & Protection Tapes
# Trying Adhesion & Protection Tapes with 3 unexplored child nodes.
# Chose Adhesive and Insulation Tapes
# Trying chosen subtree.
# Entering Adhesive and Insulation Tapes
# Trying Adhesive and Insulation Tapes with 22 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Adhesion & Protection Tapes with mask.
# Trying Adhesion & Protection Tapes with 2 unexplored child nodes.
# Chose Industrial & Safety Adhesive Tapes
# Trying chosen subtree.
# Entering Industrial & Safety Adhesive Tapes
# Trying Industrial & Safety Adhesive Tapes with 15 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Adhesion & Protection Tapes with mask.
# Trying Adhesion & Protection Tapes with 1 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying BondingTapesAndCoatings with mask.
# Trying BondingTapesAndCoatings with 2 unexplored child nodes.
# Chose ConstructionAndChemicalAdhesives
# Trying chosen subtree.
# Entering ConstructionAndChemicalAdhesives
# Trying ConstructionAndChemicalAdhesives with 9 unexplored child nodes.
# Chose Flexible General-Purpose Adhesives
# Trying chosen subtree.
# Entering Flexible General-Purpose Adhesives
# Trying Flexible General-Purpose Adhesives with 7 unexplored child nodes.
# Chose Multi purpose adhesive
# Trying chosen subtree.
# Subtree yielded choice Multi purpose adhesive.
# Yielding subtree result Multi purpose adhesive
# Subtree yielded choice Multi purpose adhesive.
# Yielding subtree result Multi purpose adhesive
# Subtree yielded choice Multi purpose adhesive.
# Yielding subtree result Multi purpose adhesive
# Subtree yielded choice Multi purpose adhesive.
# Yielding subtree result Multi purpose adhesive
# Subtree yielded choice Multi purpose adhesive.
# Yielding subtree result Multi purpose adhesive
# Subtree yielded choice Multi purpose adhesive.
# Yielding subtree result Multi purpose adhesive
# Subtree yielded choice Multi purpose adhesive.
# Yielding subtree result Multi purpose adhesive
# Entering BusinessAndIndustrialSolutions
# Trying BusinessAndIndustrialSolutions with 18 unexplored child nodes.
# Chose Educational Supplies & Toys: STEM Resources, Arts, Music & Classroom Decor
# Trying chosen subtree.
# Entering Educational Supplies & Toys: STEM Resources, Arts, Music & Classroom Decor
# Trying Educational Supplies & Toys: STEM Resources, Arts, Music & Classroom Decor with 5 unexplored child nodes.
# Chose Children's Playsets and Games
# Trying chosen subtree.
# Entering Children's Playsets and Games
# Trying Children's Playsets and Games with 5 unexplored child nodes.
# Chose Pretend Play Props & Sets
# Trying chosen subtree.
# Entering Pretend Play Props & Sets
# Trying Pretend Play Props & Sets with 5 unexplored child nodes.
# Chose Pretend play kits or supplies
# Trying chosen subtree.
# Subtree yielded choice Pretend play kits or supplies.
# Yielding subtree result Pretend play kits or supplies
# Subtree yielded choice Pretend play kits or supplies.
# Yielding subtree result Pretend play kits or supplies
# Subtree yielded choice Pretend play kits or supplies.
# Yielding subtree result Pretend play kits or supplies
# Subtree yielded choice Pretend play kits or supplies.
# Yielding subtree result Pretend play kits or supplies
# Entering BusinessAndIndustrialSolutions
# Trying BusinessAndIndustrialSolutions with 18 unexplored child nodes.
# Chose Electronics & Telecom Hardware Solutions
# Trying chosen subtree.
# Entering Electronics & Telecom Hardware Solutions
# Trying Electronics & Telecom Hardware Solutions with 4 unexplored child nodes.
# Chose Advanced Electronic & Semiconductor Components
# Trying chosen subtree.
# Entering Advanced Electronic & Semiconductor Components
# Trying Advanced Electronic & Semiconductor Components with 6 unexplored child nodes.
# Chose Electrical Passives and Filters
# Trying chosen subtree.
# Entering Electrical Passives and Filters
# Trying Electrical Passives and Filters with 5 unexplored child nodes.
# Chose RF and Crystal Filters
# Trying chosen subtree.
# Entering RF and Crystal Filters
# Trying RF and Crystal Filters with 4 unexplored child nodes.
# Chose Microwave filter
# Trying chosen subtree.
# Subtree yielded choice Microwave filter.
# Yielding subtree result Microwave filter
# Subtree yielded choice Microwave filter.
# Yielding subtree result Microwave filter
# Subtree yielded choice Microwave filter.
# Yielding subtree result Microwave filter
# Subtree yielded choice Microwave filter.
# Yielding subtree result Microwave filter
# Subtree yielded choice Microwave filter.
# Yielding subtree result Microwave filter
# Entering BusinessAndIndustrialSolutions
# Trying BusinessAndIndustrialSolutions with 18 unexplored child nodes.
# Chose FashionTravelPersonalEssentials
# Trying chosen subtree.
# Entering FashionTravelPersonalEssentials
# Trying FashionTravelPersonalEssentials with 5 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying BusinessAndIndustrialSolutions with mask.
# Trying BusinessAndIndustrialSolutions with 17 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Entering BusinessAndIndustrialSolutions
# Trying BusinessAndIndustrialSolutions with 18 unexplored child nodes.
# Chose FashionTravelPersonalEssentials
# Trying chosen subtree.
# Entering FashionTravelPersonalEssentials
# Trying FashionTravelPersonalEssentials with 5 unexplored child nodes.
# Chose Comprehensive Apparel by Gender & Age
# Trying chosen subtree.
# Entering Comprehensive Apparel by Gender & Age
# Trying Comprehensive Apparel by Gender & Age with 18 unexplored child nodes.
# Chose Gender-Specific Shirts & Blouses
# Trying chosen subtree.
# Entering Gender-Specific Shirts & Blouses
# Trying Gender-Specific Shirts & Blouses with 5 unexplored child nodes.
# Chose Mens shirts
# Trying chosen subtree.
# Subtree yielded choice Mens shirts.
# Yielding subtree result Mens shirts
# Subtree yielded choice Mens shirts.
# Yielding subtree result Mens shirts
# Subtree yielded choice Mens shirts.
# Yielding subtree result Mens shirts
# Subtree yielded choice Mens shirts.
# Yielding subtree result Mens shirts
# Entering BusinessAndIndustrialSolutions
# Trying BusinessAndIndustrialSolutions with 18 unexplored child nodes.
# Chose FashionTravelPersonalEssentials
# Trying chosen subtree.
# Entering FashionTravelPersonalEssentials
# Trying FashionTravelPersonalEssentials with 5 unexplored child nodes.
# Chose Travel Carriers & Accessories
# Trying chosen subtree.
# Entering Travel Carriers & Accessories
# Trying Travel Carriers & Accessories with 4 unexplored child nodes.
# Chose Travel Bags & Sets
# Trying chosen subtree.
# Entering Travel Bags & Sets
# Trying Travel Bags & Sets with 3 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Travel Carriers & Accessories with mask.
# Trying Travel Carriers & Accessories with 3 unexplored child nodes.
# Chose Personal Carry Items
# Trying chosen subtree.
# Entering Personal Carry Items
# Trying Personal Carry Items with 7 unexplored child nodes.
# Chose Backpacks
# Trying chosen subtree.
# Subtree yielded choice Backpacks.
# Yielding subtree result Backpacks
# Subtree yielded choice Backpacks.
# Yielding subtree result Backpacks
# Subtree yielded choice Backpacks.
# Yielding subtree result Backpacks
# Subtree yielded choice Backpacks.
# Yielding subtree result Backpacks
# Entering BusinessAndIndustrialSolutions
# Trying BusinessAndIndustrialSolutions with 18 unexplored child nodes.
# Chose Watches, Jewelry & Gemstones
# Trying chosen subtree.
# Entering Watches, Jewelry & Gemstones
# Trying Watches, Jewelry & Gemstones with 3 unexplored child nodes.
# Chose Jewelry and Crafting Supplies
# Trying chosen subtree.
# Entering Jewelry and Crafting Supplies
# Trying Jewelry and Crafting Supplies with 3 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Watches, Jewelry & Gemstones with mask.
# Trying Watches, Jewelry & Gemstones with 2 unexplored child nodes.
# Chose Jewelry_and_Industrial_Gemstones
# Trying chosen subtree.
# Entering Jewelry_and_Industrial_Gemstones
# Trying Jewelry_and_Industrial_Gemstones with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying Watches, Jewelry & Gemstones with mask.
# Trying Watches, Jewelry & Gemstones with 1 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying BusinessAndIndustrialSolutions with mask.
# Trying BusinessAndIndustrialSolutions with 17 unexplored child nodes.
# Chose FashionTravelPersonalEssentials
# Trying chosen subtree.
# Entering FashionTravelPersonalEssentials
# Trying FashionTravelPersonalEssentials with 5 unexplored child nodes.
# Chose Gender-Age Specific Footwear & Accessories
# Trying chosen subtree.
# Entering Gender-Age Specific Footwear & Accessories
# Trying Gender-Age Specific Footwear & Accessories with 7 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying FashionTravelPersonalEssentials with mask.
# Trying FashionTravelPersonalEssentials with 4 unexplored child nodes.
# Chose OralCare_Beauty_Massagers_TattooSupplies
# Trying chosen subtree.
# Entering OralCare_Beauty_Massagers_TattooSupplies
# Trying OralCare_Beauty_Massagers_TattooSupplies with 4 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying FashionTravelPersonalEssentials with mask.
# Trying FashionTravelPersonalEssentials with 3 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying BusinessAndIndustrialSolutions with mask.
# Trying BusinessAndIndustrialSolutions with 16 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Saved classifications from tree_improved.pkl to classification_results/classifications_improved_tree.csv
