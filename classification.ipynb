# %%
import pickle
from model import Node, categorize_next, display_lazy_tree, format_node, format_time

# %%
import chardet

with open("amazon_products.csv", 'rb') as f:
    result = chardet.detect(f.read(8*1024*1024))
    print(result)
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
import pandas as pd
df = pd.read_csv("amazon_products.csv", encoding=result["encoding"])

# %%
df = df.sample(20000)
df.head()
# Out:
#                asin                                              title  \
# 1206274  B00JY090KS                 Daystar MX30013RE Mud Scraper, Red
# 110582   B083XYM53Z  Fielect 3Pcs Carbon Fiber Strip Bars 2x10x600m...
# 369706   B0C1Z8866Y  Arcade Game Console Pandora Box Built in 10000...
# 1019835  B0BM735RF5  Wood Cutting Boards for Kitchen, Large Cutting...
# 110404   B09YQ13MC2  Swpeet 15Pcs Milkly Plastic Rods Assortment Ki...
#
#                                                     imgUrl  \
# 1206274  https://m.media-amazon.com/images/I/51lJm81a5U...
# 110582   https://m.media-amazon.com/images/I/51MO9GN3sX...
# 369706   https://m.media-amazon.com/images/I/81XWHRgx+5...
# 1019835  https://m.media-amazon.com/images/I/71MeZTjGwg...
# 110404   https://m.media-amazon.com/images/I/51lrTdtxV5...
#
#                                    productURL  stars  reviews   price  \
# 1206274  https://www.amazon.com/dp/B00JY090KS    4.1        0   23.28
# 110582   https://www.amazon.com/dp/B083XYM53Z    4.8        9   21.89
# 369706   https://www.amazon.com/dp/B0C1Z8866Y    3.4        0  109.99
# 1019835  https://www.amazon.com/dp/B0BM735RF5    4.5        0   39.99
# 110404   https://www.amazon.com/dp/B09YQ13MC2    4.7        4    7.98
#
#          listPrice  category_id  isBestSeller  boughtInLastMonth
# 1206274        0.0           19         False                  0
# 110582         0.0          140         False                  0
# 369706         0.0          222         False                  0
# 1019835        0.0          170         False                800
# 110404         0.0          140         False                  0

# %%
with open("./tree_v3_improved.pkl", "rb") as f:
    root = pickle.load(f)

# %%
from typing import Callable, Optional, Tuple
from langchain_core.language_models.chat_models import BaseChatModel

from model.data import TokenCounts

def classify(item_description: str, root: Node, create_llm: Callable[[], BaseChatModel]) -> Tuple[Optional[Node], TokenCounts]:
    def classify_recur(item_description: str, node: Node) -> Tuple[Optional[Node], TokenCounts]:
        if node.is_leaf():
            return node, TokenCounts()
        children = [*node.children]
        all_tokens = TokenCounts()
        print(f"Entering {node.condition}")
        while len(children) > 0:
            print(f"Trying {node.condition} with {len(children)} unexplored child nodes.")
            choice, tokens = categorize_next(item_description=item_description, nodes=children, create_llm=create_llm)
            print(f"Chose {choice.condition if choice else "None"}")
            all_tokens += tokens
            if choice is None:
                print(f"Retrying previous node with mask.")
                return (None, all_tokens)
            
            print(f"Trying chosen subtree.")
            result, tokens = classify_recur(item_description=item_description, node=choice)
            print(f"Subtree yielded choice {result.condition if result else "None"}.")
            all_tokens += tokens
            if result is not None:
                print(f"Yielding subtree result {result.condition}")
                return (result, all_tokens)
            
            print(f"Retrying {node.condition} with mask.")
            children.remove(choice)
            
        return None, all_tokens
            
    return classify_recur(item_description=item_description, node=root)

# %%
from langchain_ollama import ChatOllama
create_llm = lambda: ChatOllama(
    model="qwen2.5:32b",
    # temperature=0,
)

# %%
display_lazy_tree(root, max_initial_depth=5)
# Out:
# VBox(children=(FigureWidget({
#     'data': [{'branchvalues': 'total',
#               'ids': [5c070ee8-39ba-49d4-…

# %%
from pydantic import BaseModel, Field
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import HumanMessage
from langchain_community.callbacks import get_openai_callback


class Description(BaseModel):
    reasoning: str = Field(description="Reasoning on your choice.")
    description: str = Field(description="The shortened description")

def prompt_tentative_description(item_description: str, create_llm: Callable[[], BaseChatModel]) -> Tuple[Description, TokenCounts]:
    template = """
    From the given e-commerce item description give a simplified short, generic description that would be useful in categorizing an item into product standardizations.
    From specific product names and branding provide a description that includes the true nature of the product.
    Use the given tool to provide your answer.
    
    {item}
    """.strip()
    
    prompt = ChatPromptTemplate.from_template(template)
    prompt = prompt.format(item=item_description)
    
    with get_openai_callback() as cb:
        llm = create_llm().with_structured_output(Description)
        response = llm.invoke([HumanMessage(prompt)])
        
    return response, TokenCounts(prompt=cb.prompt_tokens, completion=cb.completion_tokens, total=cb.total_tokens)

# %%
from ipywidgets import IntProgress, VBox, Label
from IPython.display import display
import time

def create_classification_sample(df: pd.DataFrame, root: Node) -> Tuple[pd.DataFrame, TokenCounts]:
    items: list[dict[str, any]] = []
    all_tokens = TokenCounts()

    total_rows = len(df)
    progress_bar = IntProgress(min=0, max=total_rows, description='Progress:', bar_style='info')
    label = Label(value=f"0/{total_rows} items processed")
    time_label = Label(value="Estimating time...")
    display(VBox([progress_bar, label, time_label]))

    processed_rows = 0
    start_time = time.time()

    for i, row in df.iterrows():
        print(f"\tItem: {row['title']}")
        short_desc, desc_tokens = prompt_tentative_description(item_description=row["title"], create_llm=create_llm)
        print(f"\tShort Desc: {short_desc.description}")
        node, tokens = classify(item_description=short_desc.description, root=root, create_llm=create_llm)
        record = {
            "item": row["title"],
            "imputed_desc": short_desc.description,
            "classification": format_node(node) if node else "None"
        }
        items.append(record)
        all_tokens += tokens + desc_tokens

        processed_rows += 1
        elapsed_time = time.time() - start_time
        progress_bar.value = processed_rows
        label.value = f"{processed_rows}/{total_rows} items processed"
        estimated_total_time = elapsed_time / processed_rows * total_rows
        remaining_time = estimated_total_time - elapsed_time
        time_label.value = f"Estimated remaining time: {format_time(remaining_time)}"

    result = pd.DataFrame(items)
    return result, all_tokens

# %%
df_sample = df.sample(100)

args: list[dict[str,any]] = [
    # {
    #     "model_file": "tree_v3.pkl",
    #     "output_file": "classifications_v3.csv"
    # },
    {
        "model_file": "tree_v3_improved.pkl",
        "output_file": "classifications_v3_improved.csv"
    }
]

output_dir = "classification_results"
tokens_output_file = "tokens.csv"

import os
import time

os.makedirs(output_dir, exist_ok=True)


tokens_dicts = []
for argset in args:
    start_time = time.time()
    with open(argset["model_file"], "rb") as f:
        root = pickle.load(f)
    
    out_df, tokens = create_classification_sample(df_sample, root)
    elapsed_time = time.time() - start_time
    tokens_dicts.append({
        **argset,
        "prompt": tokens.prompt,
        "completion": tokens.completion,
        "total": tokens.total,
        "elapsed_seconds": elapsed_time
    })
    out_df.to_csv(argset["output_file"])
    print(f"Saved classifications from {argset['model_file']} to {output_dir}/{argset['output_file']}")
    
tokens_df = pd.DataFrame(tokens_dicts)
tokens_df.to_csv(tokens_output_file)
# Out:
# VBox(children=(IntProgress(value=0, bar_style='info', description='Progress:'), Label(value='0/100 items proce…
# 	Item: Luminara Moving Flame LED Flameless Tealight (1.4" x 2") Remote Ready Battery Operated Plastic LED Flameless Tea Light - Smooth Matte - Pearl Ivory (4-Pack)
# 	Short Desc: Flameless LED tea light - battery operated plastic candle alternative in pearl ivory color (pack of 4)
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose HomeAutomationAndDecor
# Trying chosen subtree.
# Entering HomeAutomationAndDecor
# Trying HomeAutomationAndDecor with 25 unexplored child nodes.
# Chose Home Decor & Crafting Supplies
# Trying chosen subtree.
# Entering Home Decor & Crafting Supplies
# Trying Home Decor & Crafting Supplies with 5 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying HomeAutomationAndDecor with mask.
# Trying HomeAutomationAndDecor with 24 unexplored child nodes.
# Chose Seasonal Décor
# Trying chosen subtree.
# Subtree yielded choice Seasonal Décor.
# Yielding subtree result Seasonal Décor
# Subtree yielded choice Seasonal Décor.
# Yielding subtree result Seasonal Décor
# 	Item: Long Range Bluetooth 5.3 Adapter for PC USB High Gain 5dBi 100m/492ft Antenna for Desktop Laptop Bluetooth Dongle for Mouse, Keyboard,Speakers,Supports Windows 11/10/8.1,Plug and Play
# 	Short Desc: USB Bluetooth Adapter
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose Consumer Electronics & Accessories
# Trying chosen subtree.
# Entering Consumer Electronics & Accessories
# Trying Consumer Electronics & Accessories with 21 unexplored child nodes.
# Chose Computer Hardware & Accessories
# Trying chosen subtree.
# Entering Computer Hardware & Accessories
# Trying Computer Hardware & Accessories with 10 unexplored child nodes.
# Chose Computer External Components
# Trying chosen subtree.
# Subtree yielded choice Computer External Components.
# Yielding subtree result Computer External Components
# Subtree yielded choice Computer External Components.
# Yielding subtree result Computer External Components
# Subtree yielded choice Computer External Components.
# Yielding subtree result Computer External Components
# 	Item: IKXO Neckband Bluetooth Headphones Noise Cancelling Headset with Mic Wireless Earbuds 5.0 CVC 8.0 Waterproof Sport Earphones for Running Driving Working Compatible
# 	Short Desc: Wireless Noise-Cancelling Waterproof Neckband Earbuds
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose Consumer Electronics & Accessories
# Trying chosen subtree.
# Entering Consumer Electronics & Accessories
# Trying Consumer Electronics & Accessories with 21 unexplored child nodes.
# Chose Headphones & Earbuds
# Trying chosen subtree.
# Subtree yielded choice Headphones & Earbuds.
# Yielding subtree result Headphones & Earbuds
# Subtree yielded choice Headphones & Earbuds.
# Yielding subtree result Headphones & Earbuds
# 	Item: Scotch-Brite Scouring Pads: 6 in. x 3.8 in. (Blue) non-scratch / 3-pack
# 	Short Desc: Non-scratch scouring pads, ideal for dish and surface cleaning, sold in a pack of three.
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose HomeAutomationAndDecor
# Trying chosen subtree.
# Entering HomeAutomationAndDecor
# Trying HomeAutomationAndDecor with 25 unexplored child nodes.
# Chose Kitchen & Dining
# Trying chosen subtree.
# Subtree yielded choice Kitchen & Dining.
# Yielding subtree result Kitchen & Dining
# Subtree yielded choice Kitchen & Dining.
# Yielding subtree result Kitchen & Dining
# 	Item: Steelman 50-Foot x 3/8-Inch ID Rubber Air Hose for Pneumatic Tools, 3/8-Inch Male NPT Brass Fittings, 300-PSI Working Pressure, Abrasion/Chemical Resistant, Premium Rubber
# 	Short Desc: Rubber Air Hose, 50-Ft Long, 3/8-Inch Inner Diameter, 300 PSI Pressure Rating, Abrasion & Chemical Resistant
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose Power Transmission Products
# Trying chosen subtree.
# Subtree yielded choice Power Transmission Products.
# Yielding subtree result Power Transmission Products
# 	Item: Classic 1979 Lancer EX 2000 Turbo Evolution Model Car 1/64 Scale Diecast Toy Cars Racing Sports Rally Sedan Metal Alloy Friction Powered Vehicles, Collection for Men Boys Toys Kids Gifts, White
# 	Short Desc: 1/64 Scale Diecast Friction-Powered Model Car - Racing Sports Sedan
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose Consumer Electronics & Accessories
# Trying chosen subtree.
# Entering Consumer Electronics & Accessories
# Trying Consumer Electronics & Accessories with 21 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 19 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Minnie Mouse Girls’ Long Sleeve Shirt and Jogger Set for Infant, Toddler and Little Kids – Pink/Grey
# 	Short Desc: Infant to little kid's long sleeve shirt and jogger set - pink/grey
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose Baby & Kids Products
# Trying chosen subtree.
# Entering Baby & Kids Products
# Trying Baby & Kids Products with 24 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 19 unexplored child nodes.
# Chose FashionAndAccessories
# Trying chosen subtree.
# Entering FashionAndAccessories
# Trying FashionAndAccessories with 24 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 18 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Mobil DTE 10 Excel 32 - Formerly: Mobil DTE 13M - 5 gal. pail
# 	Short Desc: Industrial hydraulic oil - 5 gallon pail
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose Business & Industrial Supplies
# Trying chosen subtree.
# Entering Business & Industrial Supplies
# Trying Business & Industrial Supplies with 11 unexplored child nodes.
# Chose Industrial Adhesives, Sealants & Lubricants
# Trying chosen subtree.
# Subtree yielded choice Industrial Adhesives, Sealants & Lubricants.
# Yielding subtree result Industrial Adhesives, Sealants & Lubricants
# Subtree yielded choice Industrial Adhesives, Sealants & Lubricants.
# Yielding subtree result Industrial Adhesives, Sealants & Lubricants
# 	Item: Symphonized SNRGY True Wireless Earbuds – Ear Buds Wireless, Bluetooth Earbuds with Microphone, Earbud in-Ear Headphones, Earbuds Wireless Bluetooth Noise Isolating
# 	Short Desc: Wireless Bluetooth earbuds with in-ear design, microphone, and noise isolating features
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose Consumer Electronics & Accessories
# Trying chosen subtree.
# Entering Consumer Electronics & Accessories
# Trying Consumer Electronics & Accessories with 21 unexplored child nodes.
# Chose Headphones & Earbuds
# Trying chosen subtree.
# Subtree yielded choice Headphones & Earbuds.
# Yielding subtree result Headphones & Earbuds
# Subtree yielded choice Headphones & Earbuds.
# Yielding subtree result Headphones & Earbuds
# 	Item: Firefly Anticavity Fluoride Rinse, Toy Story, Alcohol Free Formula, ADA Accepted, Helps Prevent Cavities, Bubble Berry Flavor, 16 Ounce
# 	Short Desc: Anticavity Fluoride Mouth Rinse, Alcohol Free, 16 Ounce
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: Number 10 Soccer Jersey Pendant, No. 10 Jersey Soccer Necklace for Men, Number 10 Football Necklace Soccer Charm Jewelry, Rock Soccer Jersey Necklace Soccer Player Number 10 Pendant Necklace for Boys
# 	Short Desc: Soccer-themed pendant necklace featuring the number 10, suitable for men and boys.
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose FashionAndAccessories
# Trying chosen subtree.
# Entering FashionAndAccessories
# Trying FashionAndAccessories with 24 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 19 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# 	Item: 8 Pcs Truck Birthday Party Decoration, Monster Car Theme Honeycomb Centerpieces 3D Double Sided Table Decorations, Photo Booth Props for Kids Boys Girls Party Supplies
# 	Short Desc: Set of 8 Monster Truck themed party decorations including honeycomb centerpieces and photo props
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose HomeAutomationAndDecor
# Trying chosen subtree.
# Entering HomeAutomationAndDecor
# Trying HomeAutomationAndDecor with 25 unexplored child nodes.
# Chose Party Decorations
# Trying chosen subtree.
# Subtree yielded choice Party Decorations.
# Yielding subtree result Party Decorations
# Subtree yielded choice Party Decorations.
# Yielding subtree result Party Decorations
# 	Item: 70'' x 35'' Professional Poker Mat, 8 Player Portable Rubber Texas Hold'em Poker Table Top Layout w/Carrying Bag to Play Cards, Poker Games, Blackjack, Casino
# 	Short Desc: Large poker mat for up to 8 players, portable with carrying bag, suitable for card games including poker and blackjack.
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose Crafts, Sports & Travel Essentials
# Trying chosen subtree.
# Entering Crafts, Sports & Travel Essentials
# Trying Crafts, Sports & Travel Essentials with 16 unexplored child nodes.
# Chose Games & Accessories
# Trying chosen subtree.
# Subtree yielded choice Games & Accessories.
# Yielding subtree result Games & Accessories
# Subtree yielded choice Games & Accessories.
# Yielding subtree result Games & Accessories
# 	Item: 2Pcs Hanging Mesh Space Saver Bags Organizer, Foldable Stuffed Animal Storage Organizer 5 Compartments Toy Storage Organizer for Kid Room Toys, Gloves,Hats,Socks Storage Rainbow
# 	Short Desc: Hanging Foldable Multi-compartment Storage Bag
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose Tools, Equipment & Luggage
# Trying chosen subtree.
# Entering Tools, Equipment & Luggage
# Trying Tools, Equipment & Luggage with 21 unexplored child nodes.
# Chose None
# Retrying previous node with mask.
# Subtree yielded choice None.
# Retrying All Products with mask.
# Trying All Products with 19 unexplored child nodes.
# Chose Crafts, Sports & Travel Essentials
# Trying chosen subtree.
# Entering Crafts, Sports & Travel Essentials
# Trying Crafts, Sports & Travel Essentials with 16 unexplored child nodes.
# Chose Travel Accessories
# Trying chosen subtree.
# Subtree yielded choice Travel Accessories.
# Yielding subtree result Travel Accessories
# Subtree yielded choice Travel Accessories.
# Yielding subtree result Travel Accessories
# 	Item: Bladed Fury - PlayStation 4
# 	Short Desc: Action video game for PS4
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# Chose Consumer Electronics & Accessories
# Trying chosen subtree.
# Entering Consumer Electronics & Accessories
# Trying Consumer Electronics & Accessories with 21 unexplored child nodes.
# Chose Console Gaming Systems & Peripherals
# Trying chosen subtree.
# Entering Console Gaming Systems & Peripherals
# Trying Console Gaming Systems & Peripherals with 17 unexplored child nodes.
# Chose PlayStation 4 Games, Consoles & Accessories
# Trying chosen subtree.
# Subtree yielded choice PlayStation 4 Games, Consoles & Accessories.
# Yielding subtree result PlayStation 4 Games, Consoles & Accessories
# Subtree yielded choice PlayStation 4 Games, Consoles & Accessories.
# Yielding subtree result PlayStation 4 Games, Consoles & Accessories
# Subtree yielded choice PlayStation 4 Games, Consoles & Accessories.
# Yielding subtree result PlayStation 4 Games, Consoles & Accessories
# 	Item: Men Novelty Neckties Suit Accessories - Books Bookshelf Tie for Weeding Prom Reception, Party
# 	Short Desc: Men's Novelty Book Design Necktie - Formal Event Accessory
# Entering All Products
# Trying All Products with 20 unexplored child nodes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 29
#      26 with open(argset["model_file"], "rb") as f:
#      27     root = pickle.load(f)
# ---> 29 out_df, tokens = create_classification_sample(df_sample, root)
#      30 elapsed_time = time.time() - start_time
#      31 tokens_dicts.append({
#      32     **argset,
#      33     "prompt": tokens.prompt,
#    (...)     36     "elapsed_seconds": elapsed_time
#      37 })
#
# Cell In[28], line 22, in create_classification_sample(df, root)
#      20 short_desc, desc_tokens = prompt_tentative_description(item_description=row["title"], create_llm=create_llm)
#      21 print(f"\tShort Desc: {short_desc.description}")
# ---> 22 node, tokens = classify(item_description=short_desc.description, root=root, create_llm=create_llm)
#      23 record = {
#      24     "item": row["title"],
#      25     "imputed_desc": short_desc.description,
#      26     "classification": format_node(node) if node else "None"
#      27 }
#      28 items.append(record)
#
# Cell In[24], line 35, in classify(item_description, root, create_llm)
#      31         children.remove(choice)
#      33     return None, all_tokens
# ---> 35 return classify_recur(item_description=item_description, node=root)
#
# Cell In[24], line 15, in classify.<locals>.classify_recur(item_description, node)
#      13 while len(children) > 0:
#      14     print(f"Trying {node.condition} with {len(children)} unexplored child nodes.")
# ---> 15     choice, tokens = categorize_next(item_description=item_description, nodes=children, create_llm=create_llm)
#      16     print(f"Chose {choice.condition if choice else "None"}")
#      17     all_tokens += tokens
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\model\algorithm.py:257, in categorize_next(item_description, nodes, create_llm)
#     255 with get_openai_callback() as cb:
#     256     llm = create_llm().with_structured_output(CategoryChoice)
# --> 257     choice: CategoryChoice = llm.invoke([HumanMessage(prompt)])
#     259 choice_node = None
#     261 if choice.category_number - 1 < len(nodes):
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\langchain_core\runnables\base.py:3032, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3030 with set_config_context(config) as context:
#    3031     if i == 0:
# -> 3032         input = context.run(step.invoke, input, config, **kwargs)
#    3033     else:
#    3034         input = context.run(step.invoke, input, config)
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\langchain_core\runnables\base.py:5416, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5409 @override
#    5410 def invoke(
#    5411     self,
#    (...)   5414     **kwargs: Optional[Any],
#    5415 ) -> Output:
# -> 5416     return self.bound.invoke(
#    5417         input,
#    5418         self._merge_configs(config),
#    5419         **{**self.kwargs, **kwargs},
#    5420     )
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:368, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     356 @override
#     357 def invoke(
#     358     self,
#    (...)    363     **kwargs: Any,
#     364 ) -> BaseMessage:
#     365     config = ensure_config(config)
#     366     return cast(
#     367         "ChatGeneration",
# --> 368         self.generate_prompt(
#     369             [self._convert_input(input)],
#     370             stop=stop,
#     371             callbacks=config.get("callbacks"),
#     372             tags=config.get("tags"),
#     373             metadata=config.get("metadata"),
#     374             run_name=config.get("run_name"),
#     375             run_id=config.pop("run_id", None),
#     376             **kwargs,
#     377         ).generations[0][0],
#     378     ).message
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:937, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     928 @override
#     929 def generate_prompt(
#     930     self,
#    (...)    934     **kwargs: Any,
#     935 ) -> LLMResult:
#     936     prompt_messages = [p.to_messages() for p in prompts]
# --> 937     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:759, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     756 for i, m in enumerate(messages):
#     757     try:
#     758         results.append(
# --> 759             self._generate_with_cache(
#     760                 m,
#     761                 stop=stop,
#     762                 run_manager=run_managers[i] if run_managers else None,
#     763                 **kwargs,
#     764             )
#     765         )
#     766     except BaseException as e:
#     767         if run_managers:
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1002, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1000     result = generate_from_stream(iter(chunks))
#    1001 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1002     result = self._generate(
#    1003         messages, stop=stop, run_manager=run_manager, **kwargs
#    1004     )
#    1005 else:
#    1006     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\langchain_ollama\chat_models.py:715, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     708 def _generate(
#     709     self,
#     710     messages: list[BaseMessage],
#    (...)    713     **kwargs: Any,
#     714 ) -> ChatResult:
# --> 715     final_chunk = self._chat_stream_with_aggregation(
#     716         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     717     )
#     718     generation_info = final_chunk.generation_info
#     719     chat_generation = ChatGeneration(
#     720         message=AIMessage(
#     721             content=final_chunk.text,
#    (...)    726         generation_info=generation_info,
#     727     )
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\langchain_ollama\chat_models.py:652, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     643 def _chat_stream_with_aggregation(
#     644     self,
#     645     messages: list[BaseMessage],
#    (...)    649     **kwargs: Any,
#     650 ) -> ChatGenerationChunk:
#     651     final_chunk = None
# --> 652     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     653         if final_chunk is None:
#     654             final_chunk = chunk
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\langchain_ollama\chat_models.py:737, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#     730 def _iterate_over_stream(
#     731     self,
#     732     messages: list[BaseMessage],
#     733     stop: Optional[list[str]] = None,
#     734     **kwargs: Any,
#     735 ) -> Iterator[ChatGenerationChunk]:
#     736     is_thinking = False
# --> 737     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     738         if not isinstance(stream_resp, str):
#     739             if stream_resp.get("done") is True:
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\langchain_ollama\chat_models.py:639, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     636 chat_params = self._chat_params(messages, stop, **kwargs)
#     638 if chat_params["stream"]:
# --> 639     yield from self._client.chat(**chat_params)
#     640 else:
#     641     yield self._client.chat(**chat_params)
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\ollama\_client.py:170, in Client._request.<locals>.inner()
#     167   e.response.read()
#     168   raise ResponseError(e.response.text, e.response.status_code) from None
# --> 170 for line in r.iter_lines():
#     171   part = json.loads(line)
#     172   if err := part.get('error'):
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\httpx\_models.py:929, in Response.iter_lines(self)
#     927 decoder = LineDecoder()
#     928 with request_context(request=self._request):
# --> 929     for text in self.iter_text():
#     930         for line in decoder.decode(text):
#     931             yield line
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\httpx\_models.py:916, in Response.iter_text(self, chunk_size)
#     914 chunker = TextChunker(chunk_size=chunk_size)
#     915 with request_context(request=self._request):
# --> 916     for byte_content in self.iter_bytes():
#     917         text_content = decoder.decode(byte_content)
#     918         for chunk in chunker.decode(text_content):
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\gsuga\OneDrive\Desktop\Capstone\.venv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
