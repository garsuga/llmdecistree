# %% [markdown]
# # Tree Creation From Classification Labels

# %% [markdown]
# ## Method
#
# Trees are created from the classification labels only. The data to be classified is not used and therefore labeled datasets are not required for this step. Labeled datasets will be useful for evaluation instead.
#
# 'Categories', 'Conditions', and 'Labels' are used interchangeably here. Categories are created from the labels' texts and new categories will be made in the same style as the original dataset.
#
# ### Algorithms
#
# #### Tree Formation
#
# * Create the tree using any heirarchical labels in the output labels if they exist. Otherwise create a tree with a single root node and one leaf for every classification label.
# * Walk down the tree starting at the root and stop when the current node has more children than desired. Then:
#     * Place the category texts of the child nodes in a vector store and generate embeddings for each of them.
#     * Sample from the vector store to choose relatively spread out categories. This is done by performing KMeans clustering and choosing cluster representatives.
#     * Provide the LLM with representative categories and ask it to create new categories that divide those further.
#     * Classify the old child categories into the newly created categories.
#     * Place old child categories that cannot be classified into the new categories as children of the current node.
#     * Repeat this process until less than or equal to the desired number of categories is reached.
#
# #### Classification
#
# * Start at the root node and work down the tree.
# * Prompt the LLM to choose the correct next category from among the children of the current node if a valid one exists.
# * If a the LLM responds saying that node of the child categories are suitable for the item to be classified, mask/hide the current node and treat the parent of the current node as the next node.
# * If the failure above occurs while the current node is the root, the item will be skipped and receive no classification.

# %% [markdown]
# ## Code

# %% [markdown]
# ### Reading The Dataset
#
# The dataset used here is [UNSPSC Codes](https://data.ok.gov/dataset/unspsc-codes)
#
# Detect the correct charset to use when reading the categories dataset. Then read the dataset as a DataFrame.

# %%
import chardet

with open("amazon_categories.csv", 'rb') as f:
    result = chardet.detect(f.read())
    print(result)
# Out:
# {'encoding': 'utf-8', 'confidence': 0.87625, 'language': ''}

# %%
import pandas as pd

df = pd.read_csv("amazon_categories.csv", encoding=result['encoding'])

df.head()
# Out:
#    id                     category_name
# 0   1          Beading & Jewelry Making
# 1   2                 Fabric Decorating
# 2   3       Knitting & Crochet Supplies
# 3   4              Printmaking Supplies
# 4   5  Scrapbooking & Stamping Supplies

# %% [markdown]
# ### Dataset Exploration And Evaluation
#
# Test the existing heirarchical structure to determine if it can be used immediately for classification.

# %% [markdown]
# From the results above, it can be seen that with the 4 existing heirarchical levels the number of children that would be created for each node would be up to ~100. This is more than our objective of 25 children max.
#
# We will need to divide up these children to make classification using an LLM more reliable.

# %%
from model import create_tree_from_categories, check_tree, Node, display_tree, create_vector_store, ask_model_category, format_node, optimize_tree, ProgressBars, display_lazy_tree, clean_tree

# %% [markdown]
# Create the tree using the breadcrumbs present in the dataset so we can retain the existing heirarchy as a head-start.

# %%
root = create_tree_from_categories(df, condition_col="category_name", extra_cols=["category_name"])

# %% [markdown]
# Validate the new tree representation by performing a similar check to above and comparing. Things look consistent here.

# %%
check_tree(root)
# Out:
# sub_branches: 0, avg: 0.0, max: 0
#
# leaves at this level: 248
# total leaves: 248

# %% [markdown]
# Explore the new tree visually if desired. High numbers of child nodes can be seen on many of the nodes.

# %%
node = root

print(format_node(node))

display_lazy_tree(node, max_initial_depth=2)
# Out:
# All Products
# VBox(children=(FigureWidget({
#     'data': [{'branchvalues': 'total',
#               'ids': [1e622c45-7be6-49cc-…

# %% [markdown]
# Create Ollama model instances to process LLM requests locally (Change this to your desired models from LangChain)

# %%
cats = [n.condition for n in node.children]
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model="mxbai-embed-large",
)

vectorstore = create_vector_store(texts=cats, embeddings=embeddings)

from langchain_ollama import ChatOllama
create_llm = lambda: ChatOllama(
    model="qwen2.5:14b",
    # temperature=0,
)

# %% [markdown]
# Test out a single iteration of creating new categories at the root level

# %%
cats, tokens = ask_model_category(node=root, embeddings=embeddings, create_llm=create_llm)
cats
# Out:
# PROMPT:
# 	Human: Your job is to create a set categories that will serve as nodes in a tree.
#     The new nodes will lie between the parent category below and the child categories listed.
#
#     Previous categories that describe these items:
#     All Products
#
#     Direct parent category that should be divided:
#     All Products
#
#     Sample of items that should fit into the new categories:
#     Luggage
#  Boys' Clothing
#  Home Décor Products
#  Video Game Consoles & Accessories
#  Arts & Crafts Supplies
#  Girls' Accessories
#  Personal Care Products
#  Industrial Power & Hand Tools
#  Car Electronics & Accessories
#  Toys & Games
#  Smart Home: New Smart Devices
#  Kids' Play Trucks
#  Computers
#  Pumps & Plumbing Equipment
#  Lighting & Ceiling Fans
#
#
#
#     The items in the full dataset cover the scope of: Products across all industries
#
#     Provide two or more new categories to lie between the parent and children.
#     These categories should not overlap and should serve to divide the existing children between new nodes to improve search performance.
#     Only create categories that would have one or more item fit into them.
#     The categories created should cover all items that would satisfy the previous categories.
#
#     Your objective is to predict the kind of items that would be categorized using the previous categories and scope and provide a new set of categories to divide them into smaller portions.
#     Do not specify catch-all categories like "Other" and "None".
#
#     Do not create new categories that are ambigious with, duplicates of, or direct inverses of other categories listed above.
# CategoryAnswer(reasoning='To categorize the given items effectively while ensuring no overlap between categories, we need to identify common attributes or characteristics among the items that can be grouped logically. The following new categories aim at creating a more refined and organized structure that enhances search performance by dividing the existing children into smaller portions.', categories=['Travel & Outdoor', 'Home & Living', 'Electronics & Gaming', 'Arts & Hobbies', 'Personal Care & Beauty', 'Industrial Tools & Equipment', 'Vehicle Accessories', 'Toys & Educational Play'])

# %% [markdown]
# Token counts are also captured by any of the functions that interact with LLM calls

# %%
tokens
# Out:
# TokenCounts(prompt=337, completion=130, total=467)

# %% [markdown]
# The original dataset includes more categories than needed. We will be classifying consumer products from Amazon later so let's remove the extra segments and families that are irrelevant to save time optimizing the tree.
#
# We will remove all service segments and 'Food Beverage and Tabacco Products' which is very large and complex and not particularly relevant. We will also remove the 'live' and 'fresh' families.
#
# The following segments will be removed:
# * Farming and Fishing and Forestry and Wildlife Contracting Services
# * Mining and oil and gas services
# * Building and Facility Construction and Maintenance Services
# * Industrial Production and Manufacturing Services
# * Industrial Cleaning Services
# * Environmental Services
# * Transportation and Storage and Mail Services
# * Management and Business Professionals and Administrative Services
# * Engineering and Research and Technology Based Services
# * Editorial and Design and Graphic and Fine Art Services
# * Public Utilities and Public Sector Related Services
# * Financial and Insurance Services
# * Healthcare Services
# * Education and Training Services
# * Travel and Food and Lodging and Entertainment Services
# * Personal and Domestic Services
# * National Defense and Public Order and Security and Safety Services
# * Politics and Civic Affairs Services
# * Food Beverage and Tobacco Products
#
# The following families will be removed:
# * Live animals
# * Live rose bushes
# * Live plants of high species or variety count flowers
# * Live plants of low species or variety count flowers
# * Live chrysanthemums
# * Live carnations
# * Live orchids
# * Fresh cut rose
# * Fresh cut blooms of high species or variety count flowers
# * Fresh cut blooms of low species or variety count flowers
# * Fresh cut chrysanthemums
# * Fresh cut floral bouquets
# * Fresh cut carnations
# * Fresh cut orchids
# * Fresh cut greenery

# %% [markdown]
# Create a fresh tree like shown above and run the optimizer. This will create new categories as necessary and ensure that a max of 25 children will exist at any node. (This takes a very long time)

# %%
root = create_tree_from_categories(df, condition_col="category_name", extra_cols=["category_name"])
progress_bars = ProgressBars(n_leaves=len(df))
display(progress_bars.ui)
optimize_tree(root=root, max_children=15, progress_bars=progress_bars, embeddings=embeddings, create_llm=create_llm)
# Out:
# VBox(children=(IntProgress(value=0, bar_style='info', description='Leaves Completed:', layout=Layout(width='90…
# Working on node 'All Products' with 248 subcategories.
# PROMPT:
# 	Human: Your job is to create a set categories that will serve as nodes in a tree.
#     The new nodes will lie between the parent category below and the child categories listed.
#
#     Previous categories that describe these items:
#     All Products
#
#     Direct parent category that should be divided:
#     All Products
#
#     Sample of items that should fit into the new categories:
#     Luggage
#  Boys' Clothing
#  Home Décor Products
#  Video Game Consoles & Accessories
#  Arts & Crafts Supplies
#  Girls' Accessories
#  Personal Care Products
#  Industrial Power & Hand Tools
#  Car Electronics & Accessories
#  Toys & Games
#  Smart Home: New Smart Devices
#  Kids' Play Trucks
#  Computers
#  Pumps & Plumbing Equipment
#  Lighting & Ceiling Fans
#
#
#
#     The items in the full dataset cover the scope of: Products across all industries
#
#     Provide two or more new categories to lie between the parent and children.
#     These categories should not overlap and should serve to divide the existing children between new nodes to improve search performance.
#     Only create categories that would have one or more item fit into them.
#     The categories created should cover all items that would satisfy the previous categories.
#
#     Your objective is to predict the kind of items that would be categorized using the previous categories and scope and provide a new set of categories to divide them into smaller portions.
#     Do not specify catch-all categories like "Other" and "None".
#
#     Do not create new categories that are ambigious with, duplicates of, or direct inverses of other categories listed above.
#
# Created categories: ['Consumer Goods', 'Fashions & Accessories', "Boys' Clothing", "Girls' Accessories", 'Home Décor Products', 'Toys & Games', "Kids' Play Trucks", 'Electronics', 'Video Game Consoles & Accessories', 'Car Electronics & Accessories', 'Smart Home: New Smart Devices', 'Computers', 'Lighting & Ceiling Fans', 'Personal Care & Health', 'Personal Care Products', 'Industrial Supplies', 'Pumps & Plumbing Equipment', 'Industrial Power & Hand Tools']
# Rebalanced 178/248 categories.
# Failed to categorize: ['Fabric Decorating', 'Knitting & Crochet Supplies', 'Printmaking Supplies', 'Sewing Products', 'Painting, Drawing & Art Supplies', 'Craft Supplies & Materials', 'Gift Wrapping Supplies', 'Automotive Paint & Paint Supplies', 'Heavy Duty & Commercial Vehicle Equipment', 'Automotive Tires & Wheels', 'Automotive Tools & Equipment', 'Oils & Fluids', 'RV Parts & Accessories', 'Motorcycle & Powersports', 'Baby & Toddler Feeding Supplies', 'Pregnancy & Maternity Products', 'Baby Care Products', 'Baby Travel Gear', 'Baby', 'Accessories & Supplies', 'Security & Surveillance Equipment', "Boys' Watches", "Girls' Clothing", "Girls' Shoes", 'Gift Cards', 'Health Care Products', 'Sexual Wellness Products', 'Health & Household', 'Stationery & Gift Wrapping Supplies', 'Commercial Door Products', 'Power Transmission Products', 'Material Handling Products', 'Test, Measure & Inspect', 'Filtration', 'Electronic Components', 'Lab & Scientific Products', 'Janitorial & Sanitation Supplies', 'Occupational Health & Safety Products', 'Science Education Supplies', 'Food Service Equipment & Supplies', 'Additive Manufacturing Products', 'Professional Medical Supplies', 'Professional Dental Supplies', 'Packaging & Shipping Supplies', 'Retail Store Fixtures & Equipment', 'Industrial & Scientific', 'Household Cleaning Supplies', "Kids' Home Store", 'Vacuum Cleaners & Floor Care', 'Party Supplies', 'Pet Bird Supplies', 'Cat Supplies', 'Dog Supplies', 'Fish & Aquatic Pets', 'Horse Supplies', 'Reptiles & Amphibian Supplies', 'Smart Home: Lighting', 'Smart Home: Lawn and Garden', 'Sports & Fitness', 'Outdoor Recreation', 'Sports & Outdoors', 'Home Appliances', 'Safety & Security', 'Electrical Equipment', 'Building Supplies', 'Welding & Soldering', 'Tools & Home Improvement', "Kids' Party Supplies", 'Arts & Crafts Supplies', 'Toys & Games']
# Working on node 'All Products' with 88 subcategories.
# PROMPT:
# 	Human: Your job is to create a set categories that will serve as nodes in a tree.
#     The new nodes will lie between the parent category below and the child categories listed.
#
#     Previous categories that describe these items:
#     All Products
#
#     Direct parent category that should be divided:
#     All Products
#
#     Sample of items that should fit into the new categories:
#     Baby & Toddler Feeding Supplies
#  Electronics
#  Personal Care Products
#  Girls' Accessories
#  Automotive Tools & Equipment
#  Heavy Duty & Commercial Vehicle Equipment
#  Lighting & Ceiling Fans
#  Craft Supplies & Materials
#  Toys & Games
#  Building Supplies
#  Stationery & Gift Wrapping Supplies
#  Sports & Outdoors
#  Material Handling Products
#  Security & Surveillance Equipment
#  Smart Home: New Smart Devices
#
#     Previous categories you created for this parent category (provide more categories for the items above):
#             Consumer Goods
#  Fashions & Accessories
#  Boys' Clothing
#  Girls' Accessories
#  Home Décor Products
#  Toys & Games
#  Kids' Play Trucks
#  Electronics
#  Video Game Consoles & Accessories
#  Car Electronics & Accessories
#  Smart Home: New Smart Devices
#  Computers
#  Lighting & Ceiling Fans
#  Personal Care & Health
#  Personal Care Products
#  Industrial Supplies
#  Pumps & Plumbing Equipment
#  Industrial Power & Hand Tools
#
#     The items in the full dataset cover the scope of: Products across all industries
#
#     Provide two or more new categories to lie between the parent and children.
#     These categories should not overlap and should serve to divide the existing children between new nodes to improve search performance.
#     Only create categories that would have one or more item fit into them.
#     The categories created should cover all items that would satisfy the previous categories.
#
#     Your objective is to predict the kind of items that would be categorized using the previous categories and scope and provide a new set of categories to divide them into smaller portions.
#     Do not specify catch-all categories like "Other" and "None".
#
#     Do not create new categories that are ambigious with, duplicates of, or direct inverses of other categories listed above.
#
# Created categories: ['Baby & Kids Supplies', 'Electronics & Tech Accessories', 'Home Improvement & Tools', 'Automotive Parts & Equipment', 'Leisure & Hobbies']
# Rebalanced 46/88 categories.
# Failed to categorize: ['Consumer Goods', 'Fashions & Accessories', "Boys' Clothing", "Girls' Accessories", 'Personal Care & Health', 'Personal Care Products', 'Industrial Supplies', 'Printmaking Supplies', 'Gift Wrapping Supplies', 'Motorcycle & Powersports', 'Pregnancy & Maternity Products', 'Accessories & Supplies', 'Security & Surveillance Equipment', "Boys' Watches", "Girls' Clothing", 'Gift Cards', 'Health Care Products', 'Sexual Wellness Products', 'Health & Household', 'Stationery & Gift Wrapping Supplies', 'Power Transmission Products', 'Material Handling Products', 'Filtration', 'Lab & Scientific Products', 'Janitorial & Sanitation Supplies', 'Occupational Health & Safety Products', 'Science Education Supplies', 'Food Service Equipment & Supplies', 'Additive Manufacturing Products', 'Professional Medical Supplies', 'Professional Dental Supplies', 'Packaging & Shipping Supplies', 'Industrial & Scientific', 'Party Supplies', 'Pet Bird Supplies', 'Dog Supplies', 'Fish & Aquatic Pets', 'Horse Supplies', 'Reptiles & Amphibian Supplies', 'Sports & Outdoors', 'Home Appliances', "Kids' Party Supplies"]
# Working on node 'All Products' with 47 subcategories.
# PROMPT:
# 	Human: Your job is to create a set categories that will serve as nodes in a tree.
#     The new nodes will lie between the parent category below and the child categories listed.
#
#     Previous categories that describe these items:
#     All Products
#
#     Direct parent category that should be divided:
#     All Products
#
#     Sample of items that should fit into the new categories:
#     Security & Surveillance Equipment
#  Professional Medical Supplies
#  Boys' Clothing
#  Baby & Kids Supplies
#  Personal Care Products
#  Occupational Health & Safety Products
#  Fashions & Accessories
#  Dog Supplies
#  Industrial Supplies
#  Accessories & Supplies
#  Gift Wrapping Supplies
#  Leisure & Hobbies
#  Filtration
#  Home Appliances
#  Fish & Aquatic Pets
#
#     Previous categories you created for this parent category (provide more categories for the items above):
#             Consumer Goods
#  Fashions & Accessories
#  Boys' Clothing
#  Girls' Accessories
#  Home Décor Products
#  Toys & Games
#  Kids' Play Trucks
#  Electronics
#  Video Game Consoles & Accessories
#  Car Electronics & Accessories
#  Smart Home: New Smart Devices
#  Computers
#  Lighting & Ceiling Fans
#  Personal Care & Health
#  Personal Care Products
#  Industrial Supplies
#  Pumps & Plumbing Equipment
#  Industrial Power & Hand Tools
#  Baby & Kids Supplies
#  Electronics & Tech Accessories
#  Home Improvement & Tools
#  Automotive Parts & Equipment
#  Leisure & Hobbies
#
#     The items in the full dataset cover the scope of: Products across all industries
#
#     Provide two or more new categories to lie between the parent and children.
#     These categories should not overlap and should serve to divide the existing children between new nodes to improve search performance.
#     Only create categories that would have one or more item fit into them.
#     The categories created should cover all items that would satisfy the previous categories.
#
#     Your objective is to predict the kind of items that would be categorized using the previous categories and scope and provide a new set of categories to divide them into smaller portions.
#     Do not specify catch-all categories like "Other" and "None".
#
#     Do not create new categories that are ambigious with, duplicates of, or direct inverses of other categories listed above.
#
# Created categories: ['Safety & Security', 'Medical Supplies', "Children's Goods", 'Pet Care', 'Home & Living', 'Industrial Solutions', 'Leisure Activities', 'Electronics & Gadgets']
# Rebalanced 22/47 categories.
# Failed to categorize: ['Automotive Parts & Equipment', 'Consumer Goods', 'Fashions & Accessories', "Girls' Accessories", 'Personal Care & Health', 'Personal Care Products', 'Printmaking Supplies', 'Motorcycle & Powersports', 'Pregnancy & Maternity Products', 'Accessories & Supplies', 'Gift Cards', 'Sexual Wellness Products', 'Health & Household', 'Stationery & Gift Wrapping Supplies', 'Material Handling Products', 'Lab & Scientific Products', 'Janitorial & Sanitation Supplies', 'Science Education Supplies', 'Food Service Equipment & Supplies', 'Professional Dental Supplies', 'Packaging & Shipping Supplies', 'Industrial & Scientific', 'Horse Supplies', 'Reptiles & Amphibian Supplies', 'Sports & Outdoors']
# Working on node 'All Products' with 33 subcategories.
# PROMPT:
# 	Human: Your job is to create a set categories that will serve as nodes in a tree.
#     The new nodes will lie between the parent category below and the child categories listed.
#
#     Previous categories that describe these items:
#     All Products
#
#     Direct parent category that should be divided:
#     All Products
#
#     Sample of items that should fit into the new categories:
#     Personal Care & Health
#  Stationery & Gift Wrapping Supplies
#  Professional Dental Supplies
#  Leisure Activities
#  Material Handling Products
#  Children's Goods
#  Fashions & Accessories
#  Food Service Equipment & Supplies
#  Safety & Security
#  Reptiles & Amphibian Supplies
#  Motorcycle & Powersports
#  Industrial & Scientific
#  Gift Cards
#  Horse Supplies
#  Science Education Supplies
#
#     Previous categories you created for this parent category (provide more categories for the items above):
#             Consumer Goods
#  Fashions & Accessories
#  Boys' Clothing
#  Girls' Accessories
#  Home Décor Products
#  Toys & Games
#  Kids' Play Trucks
#  Electronics
#  Video Game Consoles & Accessories
#  Car Electronics & Accessories
#  Smart Home: New Smart Devices
#  Computers
#  Lighting & Ceiling Fans
#  Personal Care & Health
#  Personal Care Products
#  Industrial Supplies
#  Pumps & Plumbing Equipment
#  Industrial Power & Hand Tools
#  Baby & Kids Supplies
#  Electronics & Tech Accessories
#  Home Improvement & Tools
#  Automotive Parts & Equipment
#  Leisure & Hobbies
#  Safety & Security
#  Medical Supplies
#  Children's Goods
#  Pet Care
#  Home & Living
#  Industrial Solutions
#  Leisure Activities
#  Electronics & Gadgets
#
#     The items in the full dataset cover the scope of: Products across all industries
#
#     Provide two or more new categories to lie between the parent and children.
#     These categories should not overlap and should serve to divide the existing children between new nodes to improve search performance.
#     Only create categories that would have one or more item fit into them.
#     The categories created should cover all items that would satisfy the previous categories.
#
#     Your objective is to predict the kind of items that would be categorized using the previous categories and scope and provide a new set of categories to divide them into smaller portions.
#     Do not specify catch-all categories like "Other" and "None".
#
#     Do not create new categories that are ambigious with, duplicates of, or direct inverses of other categories listed above.
#
# Created categories: ['Health & Wellness', 'Office Essentials', 'Professional Supplies', 'Leisure & Entertainment', 'Industrial Tools & Equipment', 'Pet Care & Animal Supplies', 'Food Service & Catering', 'Safety Gear & Devices', 'Reptile & Amphibian Care', 'Motor Vehicle Accessories', 'Home & Garden Decorations', "Children's Learning & Play"]
# Rebalanced 21/33 categories.
# Failed to categorize: ['Home & Living', 'Electronics & Gadgets', 'Consumer Goods', 'Fashions & Accessories', "Girls' Accessories", 'Accessories & Supplies', 'Gift Cards', 'Lab & Scientific Products', 'Janitorial & Sanitation Supplies', 'Science Education Supplies', 'Industrial & Scientific', 'Sports & Outdoors']
# Working on node 'All Products' with 23 subcategories.
# PROMPT:
# 	Human: Your job is to create a set categories that will serve as nodes in a tree.
#     The new nodes will lie between the parent category below and the child categories listed.
#
#     Previous categories that describe these items:
#     All Products
#
#     Direct parent category that should be divided:
#     All Products
#
#     Sample of items that should fit into the new categories:
#     Reptile & Amphibian Care
#  Fashions & Accessories
#  Science Education Supplies
#  Accessories & Supplies
#  Leisure & Entertainment
#  Food Service & Catering
#  Children's Learning & Play
#  Industrial & Scientific
#  Health & Wellness
#  Pet Care & Animal Supplies
#  Gift Cards
#  Office Essentials
#  Consumer Goods
#  Lab & Scientific Products
#  Electronics & Gadgets
#
#     Previous categories you created for this parent category (provide more categories for the items above):
#             Consumer Goods
#  Fashions & Accessories
#  Boys' Clothing
#  Girls' Accessories
#  Home Décor Products
#  Toys & Games
#  Kids' Play Trucks
#  Electronics
#  Video Game Consoles & Accessories
#  Car Electronics & Accessories
#  Smart Home: New Smart Devices
#  Computers
#  Lighting & Ceiling Fans
#  Personal Care & Health
#  Personal Care Products
#  Industrial Supplies
#  Pumps & Plumbing Equipment
#  Industrial Power & Hand Tools
#  Baby & Kids Supplies
#  Electronics & Tech Accessories
#  Home Improvement & Tools
#  Automotive Parts & Equipment
#  Leisure & Hobbies
#  Safety & Security
#  Medical Supplies
#  Children's Goods
#  Pet Care
#  Home & Living
#  Industrial Solutions
#  Leisure Activities
#  Electronics & Gadgets
#  Health & Wellness
#  Office Essentials
#  Professional Supplies
#  Leisure & Entertainment
#  Industrial Tools & Equipment
#  Pet Care & Animal Supplies
#  Food Service & Catering
#  Safety Gear & Devices
#  Reptile & Amphibian Care
#  Motor Vehicle Accessories
#  Home & Garden Decorations
#  Children's Learning & Play
#
#     The items in the full dataset cover the scope of: Products across all industries
#
#     Provide two or more new categories to lie between the parent and children.
#     These categories should not overlap and should serve to divide the existing children between new nodes to improve search performance.
#     Only create categories that would have one or more item fit into them.
#     The categories created should cover all items that would satisfy the previous categories.
#
#     Your objective is to predict the kind of items that would be categorized using the previous categories and scope and provide a new set of categories to divide them into smaller portions.
#     Do not specify catch-all categories like "Other" and "None".
#
#     Do not create new categories that are ambigious with, duplicates of, or direct inverses of other categories listed above.
#
# Created categories: ['Animals & Pets', 'Consumer Electronics & Gadgets', 'Education & Learning Supplies', 'Home & Living Accessories', 'Industrial & Commercial Goods', 'Leisure & Entertainment Products', 'Professional Services & Equipment', 'Science & Laboratory Tools']
# Rebalanced 12/23 categories.
# Failed to categorize: ['Health & Wellness', 'Office Essentials', 'Leisure & Entertainment', 'Food Service & Catering', 'Motor Vehicle Accessories', 'Consumer Goods', 'Fashions & Accessories', "Girls' Accessories", 'Accessories & Supplies', 'Gift Cards', 'Sports & Outdoors']
# Working on node 'All Products' with 18 subcategories.
# PROMPT:
# 	Human: Your job is to create a set categories that will serve as nodes in a tree.
#     The new nodes will lie between the parent category below and the child categories listed.
#
#     Previous categories that describe these items:
#     All Products
#
#     Direct parent category that should be divided:
#     All Products
#
#     Sample of items that should fit into the new categories:
#     Science & Laboratory Tools
#  Accessories & Supplies
#  Food Service & Catering
#  Consumer Goods
#  Education & Learning Supplies
#  Leisure & Entertainment
#  Professional Services & Equipment
#  Office Essentials
#  Animals & Pets
#  Gift Cards
#  Health & Wellness
#  Motor Vehicle Accessories
#  Girls' Accessories
#  Sports & Outdoors
#  Industrial & Commercial Goods
#
#     Previous categories you created for this parent category (provide more categories for the items above):
#             Consumer Goods
#  Fashions & Accessories
#  Boys' Clothing
#  Girls' Accessories
#  Home Décor Products
#  Toys & Games
#  Kids' Play Trucks
#  Electronics
#  Video Game Consoles & Accessories
#  Car Electronics & Accessories
#  Smart Home: New Smart Devices
#  Computers
#  Lighting & Ceiling Fans
#  Personal Care & Health
#  Personal Care Products
#  Industrial Supplies
#  Pumps & Plumbing Equipment
#  Industrial Power & Hand Tools
#  Baby & Kids Supplies
#  Electronics & Tech Accessories
#  Home Improvement & Tools
#  Automotive Parts & Equipment
#  Leisure & Hobbies
#  Safety & Security
#  Medical Supplies
#  Children's Goods
#  Pet Care
#  Home & Living
#  Industrial Solutions
#  Leisure Activities
#  Electronics & Gadgets
#  Health & Wellness
#  Office Essentials
#  Professional Supplies
#  Leisure & Entertainment
#  Industrial Tools & Equipment
#  Pet Care & Animal Supplies
#  Food Service & Catering
#  Safety Gear & Devices
#  Reptile & Amphibian Care
#  Motor Vehicle Accessories
#  Home & Garden Decorations
#  Children's Learning & Play
#  Animals & Pets
#  Consumer Electronics & Gadgets
#  Education & Learning Supplies
#  Home & Living Accessories
#  Industrial & Commercial Goods
#  Leisure & Entertainment Products
#  Professional Services & Equipment
#  Science & Laboratory Tools
#
#     The items in the full dataset cover the scope of: Products across all industries
#
#     Provide two or more new categories to lie between the parent and children.
#     These categories should not overlap and should serve to divide the existing children between new nodes to improve search performance.
#     Only create categories that would have one or more item fit into them.
#     The categories created should cover all items that would satisfy the previous categories.
#
#     Your objective is to predict the kind of items that would be categorized using the previous categories and scope and provide a new set of categories to divide them into smaller portions.
#     Do not specify catch-all categories like "Other" and "None".
#
#     Do not create new categories that are ambigious with, duplicates of, or direct inverses of other categories listed above.
#
# Created categories: ['Education & Research Supplies', 'Consumer Lifestyle Goods', 'Professional & Business Tools', 'Leisure Activities & Entertainment', 'Industrial & Commercial Equipment', 'Healthcare & Wellness Products', 'Pet Care & Animal Needs', 'Food Service & Hospitality']
# Rebalanced 16/18 categories.
# Failed to categorize: ['Motor Vehicle Accessories', 'Accessories & Supplies']
# Working on node 'Electronics' with 18 subcategories.
# PROMPT:
# 	Human: Your job is to create a set categories that will serve as nodes in a tree.
#     The new nodes will lie between the parent category below and the child categories listed.
#
#     Previous categories that describe these items:
#     Consumer Lifestyle Goods
#  Consumer Electronics & Gadgets
#  Electronics & Gadgets
#  Electronics & Tech Accessories
#  Electronics
#
#     Direct parent category that should be divided:
#     Electronics & Tech Accessories
#
#     Sample of items that should fit into the new categories:
#     Wearable Technology
#  Kids' Electronics
#  Portable Audio & Video
#  Cell Phones & Accessories
#  Computer Networking
#  Tablet Accessories
#  Computer Monitors
#  Office Electronics
#  Data Storage
#  Home Audio & Theater Products
#  Camera & Photo
#  Virtual Reality Hardware & Accessories
#  Headphones & Earbuds
#  Video Projectors
#  Televisions & Video Products
#
#
#
#     The items in the full dataset cover the scope of: Products across all industries
#
#     Provide two or more new categories to lie between the parent and children.
#     These categories should not overlap and should serve to divide the existing children between new nodes to improve search performance.
#     Only create categories that would have one or more item fit into them.
#     The categories created should cover all items that would satisfy the previous categories.
#
#     Your objective is to predict the kind of items that would be categorized using the previous categories and scope and provide a new set of categories to divide them into smaller portions.
#     Do not specify catch-all categories like "Other" and "None".
#
#     Do not create new categories that are ambigious with, duplicates of, or direct inverses of other categories listed above.
#
# Created categories: ['Portable & Wearable Technology', 'Home Entertainment & Office Electronics']
# Rebalanced 10/18 categories.
# Failed to categorize: ['Data Storage', 'Tablet Replacement Parts', 'Computer Networking', 'Laptop Accessories', 'eBook Readers & Accessories', 'Cell Phones & Accessories', 'Camera & Photo', "Kids' Electronics"]
# Working on node 'Home Décor Products' with 17 subcategories.
# PROMPT:
# 	Human: Your job is to create a set categories that will serve as nodes in a tree.
#     The new nodes will lie between the parent category below and the child categories listed.
#
#     Previous categories that describe these items:
#     Consumer Lifestyle Goods
#  Home & Living Accessories
#  Home & Living
#  Home Improvement & Tools
#  Home Décor Products
#
#     Direct parent category that should be divided:
#     Home Improvement & Tools
#
#     Sample of items that should fit into the new categories:
#     Bedding
#  Kitchen & Bath Fixtures
#  Arts, Crafts & Sewing Storage
#  Wall Art
#  Kids' Furniture
#  Seasonal Décor
#  Household Supplies
#  Heating, Cooling & Air Quality
#  Scrapbooking & Stamping Supplies
#  Ironing Products
#  Party Decorations
#  Paint, Wall Treatments & Supplies
#  Home Décor Products
#  Nursery Furniture, Bedding & Décor
#  Home Storage & Organization
#
#
#
#     The items in the full dataset cover the scope of: Products across all industries
#
#     Provide two or more new categories to lie between the parent and children.
#     These categories should not overlap and should serve to divide the existing children between new nodes to improve search performance.
#     Only create categories that would have one or more item fit into them.
#     The categories created should cover all items that would satisfy the previous categories.
#
#     Your objective is to predict the kind of items that would be categorized using the previous categories and scope and provide a new set of categories to divide them into smaller portions.
#     Do not specify catch-all categories like "Other" and "None".
#
#     Do not create new categories that are ambigious with, duplicates of, or direct inverses of other categories listed above.
#
# Created categories: ['Interior Decoration', 'DIY Projects & Craft Supplies', 'Room Organization', 'Seasonal Living', 'Kid-Friendly Furniture & Decor']
# Rebalanced 10/17 categories.
# Failed to categorize: ['Party Decorations', 'Household Supplies', 'Furniture', 'Kitchen & Dining', 'Heating, Cooling & Air Quality', 'Ironing Products', 'Kitchen & Bath Fixtures']
# Working on node 'Consumer Goods' with 17 subcategories.
# PROMPT:
# 	Human: Your job is to create a set categories that will serve as nodes in a tree.
#     The new nodes will lie between the parent category below and the child categories listed.
#
#     Previous categories that describe these items:
#     Consumer Lifestyle Goods
#  Consumer Goods
#
#     Direct parent category that should be divided:
#     Consumer Lifestyle Goods
#
#     Sample of items that should fit into the new categories:
#     Travel Tote Bags
#  Needlework Supplies
#  Baby & Child Care Products
#  Men's Watches
#  Baby Stationery
#  Luggage
#  Rain Umbrellas
#  Backpacks
#  Craft & Hobby Fabric
#  Small Animal Supplies
#  Travel Accessories
#  Laptop Bags
#  Baby Strollers & Accessories
#  Baby Safety Products
#  Suitcases
#
#
#
#     The items in the full dataset cover the scope of: Products across all industries
#
#     Provide two or more new categories to lie between the parent and children.
#     These categories should not overlap and should serve to divide the existing children between new nodes to improve search performance.
#     Only create categories that would have one or more item fit into them.
#     The categories created should cover all items that would satisfy the previous categories.
#
#     Your objective is to predict the kind of items that would be categorized using the previous categories and scope and provide a new set of categories to divide them into smaller portions.
#     Do not specify catch-all categories like "Other" and "None".
#
#     Do not create new categories that are ambigious with, duplicates of, or direct inverses of other categories listed above.
#
# Created categories: ['Travel Gear', 'Home and Baby Essentials']
# Rebalanced 14/17 categories.
# Failed to categorize: ['Craft & Hobby Fabric', 'Needlework Supplies', "Men's Watches"]
# Working on node 'Fashions & Accessories' with 16 subcategories.
# PROMPT:
# 	Human: Your job is to create a set categories that will serve as nodes in a tree.
#     The new nodes will lie between the parent category below and the child categories listed.
#
#     Previous categories that describe these items:
#     Consumer Lifestyle Goods
#  Fashions & Accessories
#
#     Direct parent category that should be divided:
#     Consumer Lifestyle Goods
#
#     Sample of items that should fit into the new categories:
#     Girls' School Uniforms
#  Men's Accessories
#  Women's Shoes
#  Women's Jewelry
#  Boys' Accessories
#  Messenger Bags
#  Baby Gifts
#  Men's Shoes
#  Beading & Jewelry Making
#  Women's Handbags
#  Garment Bags
#  Women's Accessories
#  Boys' Shoes
#  Women's Clothing
#  Men's Clothing
#
#
#
#     The items in the full dataset cover the scope of: Products across all industries
#
#     Provide two or more new categories to lie between the parent and children.
#     These categories should not overlap and should serve to divide the existing children between new nodes to improve search performance.
#     Only create categories that would have one or more item fit into them.
#     The categories created should cover all items that would satisfy the previous categories.
#
#     Your objective is to predict the kind of items that would be categorized using the previous categories and scope and provide a new set of categories to divide them into smaller portions.
#     Do not specify catch-all categories like "Other" and "None".
#
#     Do not create new categories that are ambigious with, duplicates of, or direct inverses of other categories listed above.
#
# Created categories: ['Clothing & Uniforms', 'Footwear', 'Bags & Luggage', 'Jewelry & Accessories', 'Gift Items']
# Rebalanced 16/16 categories.
# Failed to categorize: []
# Working on node 'Video Game Consoles & Accessories' with 19 subcategories.
# PROMPT:
# 	Human: Your job is to create a set categories that will serve as nodes in a tree.
#     The new nodes will lie between the parent category below and the child categories listed.
#
#     Previous categories that describe these items:
#     Leisure Activities & Entertainment
#  Leisure & Entertainment
#  Leisure Activities
#  Leisure & Hobbies
#  Video Game Consoles & Accessories
#
#     Direct parent category that should be divided:
#     Leisure & Hobbies
#
#     Sample of items that should fit into the new categories:
#     Mac Games & Accessories
#  Xbox One Games, Consoles & Accessories
#  PC Games & Accessories
#  Video Game Consoles & Accessories
#  PlayStation 5 Consoles, Games & Accessories
#  Video Games
#  Nintendo DS Games, Consoles & Accessories
#  Online Video Game Services
#  Wii U Games, Consoles & Accessories
#  Nintendo 3DS & 2DS Consoles, Games & Accessories
#  Sony PSP Games, Consoles & Accessories
#  Nintendo Switch Consoles, Games & Accessories
#  PlayStation 4 Games, Consoles & Accessories
#  PlayStation Vita Games, Consoles & Accessories
#  Xbox Series X & S Consoles, Games & Accessories
#
#
#
#     The items in the full dataset cover the scope of: Products across all industries
#
#     Provide two or more new categories to lie between the parent and children.
#     These categories should not overlap and should serve to divide the existing children between new nodes to improve search performance.
#     Only create categories that would have one or more item fit into them.
#     The categories created should cover all items that would satisfy the previous categories.
#
#     Your objective is to predict the kind of items that would be categorized using the previous categories and scope and provide a new set of categories to divide them into smaller portions.
#     Do not specify catch-all categories like "Other" and "None".
#
#     Do not create new categories that are ambigious with, duplicates of, or direct inverses of other categories listed above.
#
# Created categories: ['Console Gaming', 'Computer & Mobile Gaming']
# Rebalanced 17/19 categories.
# Failed to categorize: ['Games & Accessories', 'Video Games']
# TokenCounts(prompt=114460, completion=50551, total=165011)

# %%
clean_tree(root=root)

# %% [markdown]
# Save the tree for later.

# %%
import pickle

with open("tree_v4.pkl", "wb") as f:
    pickle.dump(root, f)

# %% [markdown]
# Test the saved tree by loading it again. (Using a copy of the file)

# %%
import pickle

with open("tree_v4.pkl", "rb") as f:
    root = pickle.load(f)

# %% [markdown]
# Explore the final tree.

# %%
check_tree(root)
# Out:
# sub_branches: 26, avg: 2.6, max: 6
#
# leaves at this level: 2
# sub_branches: 65, avg: 2.5, max: 12
#
# leaves at this level: 9
# sub_branches: 78, avg: 1.2, max: 13
#
# leaves at this level: 52
# sub_branches: 91, avg: 1.1666666666666667, max: 13
#
# leaves at this level: 66
# sub_branches: 35, avg: 0.38461538461538464, max: 13
#
# leaves at this level: 84
# sub_branches: 0, avg: 0.0, max: 0
#
# leaves at this level: 35
# total leaves: 248

# %%
root.children[0].condition
# Out:
# 'Education & Research Supplies'

# %%
display_lazy_tree(root, max_initial_depth=8)
# Out:
# VBox(children=(FigureWidget({
#     'data': [{'branchvalues': 'total',
#               'ids': [a0d9c074-bfb1-49f1-…
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
